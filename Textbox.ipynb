# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **CHECKING GRAPHICS**

# %%
# !nvidia-smi
# Out:
# Thu Mar  2 07:44:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# **CREATING ENVIRONMENT**

# %%
# %pwd
# Out:
# '/content'

# %%
cd drive/MyDrive/TextBoxes
# Out:
# /content/drive/MyDrive/TextBoxes

# %%
#cp Makefile.config.example Makefile.config

# %%
# !apt-get install caffe-cpu
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   caffe-tools-cpu cython3 fonts-lyx javascript-common libblosc1 libcaffe-cpu1
#   libgflags2.2 libgoogle-glog0v5 libimagequant0 libjs-jquery libjs-jquery-ui
#   liblbfgsb0 libleveldb1d liblzo2-2 python-matplotlib-data python-tables-data
#   python3-atomicwrites python3-attr python3-backcall python3-blosc python3-bs4
#   python3-caffe-cpu python3-cloudpickle python3-cycler python3-dask
#   python3-dateutil python3-decorator python3-et-xmlfile python3-fsspec
#   python3-gflags python3-h5py python3-html5lib python3-imageio
#   python3-importlib-metadata python3-ipython python3-ipython-genutils
#   python3-jdcal python3-jedi python3-kiwisolver python3-locket python3-lxml
#   python3-matplotlib python3-more-itertools python3-mpi4py python3-networkx
#   python3-nose python3-numexpr python3-olefile python3-openpyxl
#   python3-packaging python3-pandas python3-pandas-lib python3-parso
#   python3-partd python3-pexpect python3-pickleshare python3-pil python3-pluggy
#   python3-prompt-toolkit python3-protobuf python3-ptyprocess python3-py
#   python3-pygments python3-pyparsing python3-pytest python3-pywt python3-scipy
#   python3-skimage python3-skimage-lib python3-soupsieve python3-tables
#   python3-tables-lib python3-toolz python3-traitlets python3-tz
#   python3-wcwidth python3-webencodings python3-xlrd python3-xlwt python3-yaml
#   python3-zipp python3-zmq ttf-bitstream-vera
# Suggested packages:
#   libcaffe-cpu-dev caffe-doc cython-doc apache2 | lighttpd | httpd
#   libjs-jquery-ui-docs python-attr-doc python-blosc-doc python-cycler-doc
#   ipython python-dask-doc python3-bcolz python3-boto python3-distributed
#   python3-graphviz python3-psutil python3-sklearn python3-sqlalchemy
#   python-fsspec-doc python-h5py-doc python3-genshi python-imageio-doc
#   python3-astropy python-ipython-doc python3-lxml-dbg python-lxml-doc dvipng
#   ghostscript inkscape ipython3 python-matplotlib-doc python3-cairocffi
#   python3-gi-cairo python3-gobject python3-pyqt5 python3-sip python3-tornado
#   texlive-extra-utils texlive-latex-extra ttf-staypuft python-networkx-doc
#   python3-pygraphviz | python3-pydot python-nose-doc python-pandas-doc
#   python3-statsmodels python-pexpect-doc python-pil-doc python3-pil-dbg
#   subversion python-pygments-doc python-pyparsing-doc python-scipy-doc
#   python-skimage-doc python3-netcdf4 python-tables-doc vitables
#   python-toolz-doc python-xlrt-doc
# The following NEW packages will be installed:
#   caffe-cpu caffe-tools-cpu cython3 fonts-lyx javascript-common libblosc1
#   libcaffe-cpu1 libgflags2.2 libgoogle-glog0v5 libimagequant0 libjs-jquery
#   libjs-jquery-ui liblbfgsb0 libleveldb1d liblzo2-2 python-matplotlib-data
#   python-tables-data python3-atomicwrites python3-attr python3-backcall
#   python3-blosc python3-bs4 python3-caffe-cpu python3-cloudpickle
#   python3-cycler python3-dask python3-dateutil python3-decorator
#   python3-et-xmlfile python3-fsspec python3-gflags python3-h5py
#   python3-html5lib python3-imageio python3-importlib-metadata python3-ipython
#   python3-ipython-genutils python3-jdcal python3-jedi python3-kiwisolver
#   python3-locket python3-lxml python3-matplotlib python3-more-itertools
#   python3-mpi4py python3-networkx python3-nose python3-numexpr python3-olefile
#   python3-openpyxl python3-packaging python3-pandas python3-pandas-lib
#   python3-parso python3-partd python3-pexpect python3-pickleshare python3-pil
#   python3-pluggy python3-prompt-toolkit python3-protobuf python3-ptyprocess
#   python3-py python3-pygments python3-pyparsing python3-pytest python3-pywt
#   python3-scipy python3-skimage python3-skimage-lib python3-soupsieve
#   python3-tables python3-tables-lib python3-toolz python3-traitlets python3-tz
#   python3-wcwidth python3-webencodings python3-xlrd python3-xlwt python3-yaml
#   python3-zipp python3-zmq ttf-bitstream-vera
# 0 upgraded, 84 newly installed, 0 to remove and 19 not upgraded.
# Need to get 68.8 MB of archives.
# After this operation, 238 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-yaml amd64 5.3.1-1ubuntu0.1 [136 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgflags2.2 amd64 2.2.2-1build1 [78.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgoogle-glog0v5 amd64 0.4.0-1build1 [51.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libleveldb1d amd64 1.22-3ubuntu2 [139 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcaffe-cpu1 amd64 1.0.0+git20180821.99bd997-5build3 [790 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 caffe-tools-cpu amd64 1.0.0+git20180821.99bd997-5build3 [1,620 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 cython3 amd64 0.29.14-0.1ubuntu3 [1,474 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-dateutil all 2.7.3-3ubuntu1 [63.3 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-gflags all 1.5.1-7 [35.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-mpi4py amd64 3.0.3-4build2 [500 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-h5py amd64 2.10.0-2build2 [873 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-backcall all 0.1.0-2 [11.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-parso all 0.5.2-1ubuntu1 [62.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-jedi all 0.15.2-1 [502 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-ptyprocess all 0.6.0-1ubuntu1 [13.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-pexpect all 4.6.0-1build1 [44.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pickleshare all 0.7.5-2 [7,560 B]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-wcwidth all 0.1.8+dfsg1-3 [17.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-prompt-toolkit all 2.0.10-2 [220 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-pygments all 2.3.1+dfsg-1ubuntu2.2 [579 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-ipython-genutils all 0.2.0-1ubuntu1 [21.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-traitlets all 4.3.3-3 [59.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-ipython all 7.13.0-1 [494 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-lyx all 2.3.4.2-2 [154 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-matplotlib-data all 3.1.2-1ubuntu4 [3,788 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-pyparsing all 2.4.6-1 [61.3 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libjs-jquery all 3.3.1~dfsg-3 [329 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-cycler all 0.10.0-3 [8,132 B]
# Get:32 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-kiwisolver amd64 1.0.1-3build1 [61.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-matplotlib amd64 3.1.2-1ubuntu4 [4,459 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-networkx all 2.4-3ubuntu1 [855 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-nose all 1.3.7-5 [116 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-tz all 2019.3-1ubuntu0.20.04.0 [24.5 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pandas-lib amd64 0.25.3+dfsg-7 [4,628 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pandas all 0.25.3+dfsg-7 [1,968 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libimagequant0 amd64 2.12.2-1.1 [31.4 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-pil amd64 7.0.0-4ubuntu0.7 [366 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-protobuf amd64 3.6.1.3-2ubuntu5 [298 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/universe amd64 liblbfgsb0 amd64 3.0+dfsg.3-7build1 [29.5 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-scipy amd64 1.3.3-3build1 [11.1 MB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-skimage-lib amd64 0.16.2-2ubuntu1 [2,217 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-imageio all 2.4.1-3 [3,187 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pywt amd64 0.5.1-1.3build1 [998 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-skimage all 0.16.2-2ubuntu1 [20.5 MB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-caffe-cpu amd64 1.0.0+git20180821.99bd997-5build3 [698 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/universe amd64 caffe-cpu amd64 1.0.0+git20180821.99bd997-5build3 [4,604 B]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 javascript-common all 11 [6,066 B]
# Get:51 http://archive.ubuntu.com/ubuntu focal/universe amd64 libblosc1 amd64 1.17.1+ds1-1 [32.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:53 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-tables-data all 3.6.1-2build1 [45.7 kB]
# Get:54 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-atomicwrites all 1.1.5-2build1 [7,016 B]
# Get:55 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-attr all 19.3.0-2 [33.9 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-blosc amd64 1.7.0+ds1-2ubuntu2 [22.0 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-soupsieve all 1.9.5+dfsg-1 [29.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-bs4 all 4.8.2-1 [83.0 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-cloudpickle all 1.3.0-1 [23.4 kB]
# Get:60 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-fsspec all 0.6.1-0.1 [45.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-toolz all 0.9.0-1 [42.0 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-dask all 2.8.1+dfsg-0.4 [532 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-et-xmlfile all 1.0.1-2.1 [9,224 B]
# Get:64 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-webencodings all 0.5.1-1ubuntu1 [11.0 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-html5lib all 1.0.1-2 [84.3 kB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-more-itertools all 4.2.0-1build1 [39.4 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-zipp all 1.0.0-1 [5,312 B]
# Get:68 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-importlib-metadata all 1.5.0-1 [9,992 B]
# Get:69 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-jdcal all 1.0-1.3 [7,944 B]
# Get:70 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-locket all 0.2.0-1 [4,562 B]
# Get:71 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-lxml amd64 4.5.0-1ubuntu0.5 [1,384 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-numexpr amd64 2.7.1-1build1 [133 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-olefile all 0.46-2 [33.7 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-openpyxl all 3.0.3-1 [144 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-packaging all 20.3-1 [26.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-partd all 1.0.0-1 [14.8 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pluggy all 0.13.0-2 [18.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-py all 1.8.1-1ubuntu0.1 [65.6 kB]
# Get:79 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pytest all 4.6.9-1 [178 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-tables-lib amd64 3.6.1-2build1 [501 kB]
# Get:81 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-tables all 3.6.1-2build1 [333 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-xlrd all 1.1.0-5 [90.8 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-xlwt all 1.3.0-3 [83.7 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-zmq amd64 18.1.1-3 [294 kB]
# Fetched 68.8 MB in 9s (7,814 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package python3-yaml.
# (Reading database ... 128221 files and directories currently installed.)
# Preparing to unpack .../00-python3-yaml_5.3.1-1ubuntu0.1_amd64.deb ...
# Unpacking python3-yaml (5.3.1-1ubuntu0.1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../01-libgflags2.2_2.2.2-1build1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-1build1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../02-libgoogle-glog0v5_0.4.0-1build1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.4.0-1build1) ...
# Selecting previously unselected package libleveldb1d:amd64.
# Preparing to unpack .../03-libleveldb1d_1.22-3ubuntu2_amd64.deb ...
# Unpacking libleveldb1d:amd64 (1.22-3ubuntu2) ...
# Selecting previously unselected package libcaffe-cpu1:amd64.
# Preparing to unpack .../04-libcaffe-cpu1_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking libcaffe-cpu1:amd64 (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package caffe-tools-cpu.
# Preparing to unpack .../05-caffe-tools-cpu_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking caffe-tools-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package cython3.
# Preparing to unpack .../06-cython3_0.29.14-0.1ubuntu3_amd64.deb ...
# Unpacking cython3 (0.29.14-0.1ubuntu3) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../07-python3-dateutil_2.7.3-3ubuntu1_all.deb ...
# Unpacking python3-dateutil (2.7.3-3ubuntu1) ...
# Selecting previously unselected package python3-gflags.
# Preparing to unpack .../08-python3-gflags_1.5.1-7_all.deb ...
# Unpacking python3-gflags (1.5.1-7) ...
# Selecting previously unselected package python3-mpi4py.
# Preparing to unpack .../09-python3-mpi4py_3.0.3-4build2_amd64.deb ...
# Unpacking python3-mpi4py (3.0.3-4build2) ...
# Selecting previously unselected package python3-h5py.
# Preparing to unpack .../10-python3-h5py_2.10.0-2build2_amd64.deb ...
# Unpacking python3-h5py (2.10.0-2build2) ...
# Selecting previously unselected package python3-backcall.
# Preparing to unpack .../11-python3-backcall_0.1.0-2_all.deb ...
# Unpacking python3-backcall (0.1.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../12-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../13-python3-parso_0.5.2-1ubuntu1_all.deb ...
# Unpacking python3-parso (0.5.2-1ubuntu1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../14-python3-jedi_0.15.2-1_all.deb ...
# Unpacking python3-jedi (0.15.2-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../15-python3-ptyprocess_0.6.0-1ubuntu1_all.deb ...
# Unpacking python3-ptyprocess (0.6.0-1ubuntu1) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../16-python3-pexpect_4.6.0-1build1_all.deb ...
# Unpacking python3-pexpect (4.6.0-1build1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../17-python3-pickleshare_0.7.5-2_all.deb ...
# Unpacking python3-pickleshare (0.7.5-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../18-python3-wcwidth_0.1.8+dfsg1-3_all.deb ...
# Unpacking python3-wcwidth (0.1.8+dfsg1-3) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../19-python3-prompt-toolkit_2.0.10-2_all.deb ...
# Unpacking python3-prompt-toolkit (2.0.10-2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../20-python3-pygments_2.3.1+dfsg-1ubuntu2.2_all.deb ...
# Unpacking python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../21-python3-ipython-genutils_0.2.0-1ubuntu1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../22-python3-traitlets_4.3.3-3_all.deb ...
# Unpacking python3-traitlets (4.3.3-3) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../23-python3-ipython_7.13.0-1_all.deb ...
# Unpacking python3-ipython (7.13.0-1) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../24-fonts-lyx_2.3.4.2-2_all.deb ...
# Unpacking fonts-lyx (2.3.4.2-2) ...
# Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../25-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../26-python-matplotlib-data_3.1.2-1ubuntu4_all.deb ...
# Unpacking python-matplotlib-data (3.1.2-1ubuntu4) ...
# Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../27-python3-pyparsing_2.4.6-1_all.deb ...
# Unpacking python3-pyparsing (2.4.6-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../28-libjs-jquery_3.3.1~dfsg-3_all.deb ...
# Unpacking libjs-jquery (3.3.1~dfsg-3) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../29-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# Selecting previously unselected package python3-cycler.
# Preparing to unpack .../30-python3-cycler_0.10.0-3_all.deb ...
# Unpacking python3-cycler (0.10.0-3) ...
# Selecting previously unselected package python3-kiwisolver.
# Preparing to unpack .../31-python3-kiwisolver_1.0.1-3build1_amd64.deb ...
# Unpacking python3-kiwisolver (1.0.1-3build1) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../32-python3-matplotlib_3.1.2-1ubuntu4_amd64.deb ...
# Unpacking python3-matplotlib (3.1.2-1ubuntu4) ...
# Selecting previously unselected package python3-networkx.
# Preparing to unpack .../33-python3-networkx_2.4-3ubuntu1_all.deb ...
# Unpacking python3-networkx (2.4-3ubuntu1) ...
# Selecting previously unselected package python3-nose.
# Preparing to unpack .../34-python3-nose_1.3.7-5_all.deb ...
# Unpacking python3-nose (1.3.7-5) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../35-python3-tz_2019.3-1ubuntu0.20.04.0_all.deb ...
# Unpacking python3-tz (2019.3-1ubuntu0.20.04.0) ...
# Selecting previously unselected package python3-pandas-lib.
# Preparing to unpack .../36-python3-pandas-lib_0.25.3+dfsg-7_amd64.deb ...
# Unpacking python3-pandas-lib (0.25.3+dfsg-7) ...
# Selecting previously unselected package python3-pandas.
# Preparing to unpack .../37-python3-pandas_0.25.3+dfsg-7_all.deb ...
# Unpacking python3-pandas (0.25.3+dfsg-7) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../38-libimagequant0_2.12.2-1.1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.12.2-1.1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../39-python3-pil_7.0.0-4ubuntu0.7_amd64.deb ...
# Unpacking python3-pil:amd64 (7.0.0-4ubuntu0.7) ...
# Selecting previously unselected package python3-protobuf.
# Preparing to unpack .../40-python3-protobuf_3.6.1.3-2ubuntu5_amd64.deb ...
# Unpacking python3-protobuf (3.6.1.3-2ubuntu5) ...
# Selecting previously unselected package liblbfgsb0:amd64.
# Preparing to unpack .../41-liblbfgsb0_3.0+dfsg.3-7build1_amd64.deb ...
# Unpacking liblbfgsb0:amd64 (3.0+dfsg.3-7build1) ...
# Selecting previously unselected package python3-scipy.
# Preparing to unpack .../42-python3-scipy_1.3.3-3build1_amd64.deb ...
# Unpacking python3-scipy (1.3.3-3build1) ...
# Selecting previously unselected package python3-skimage-lib:amd64.
# Preparing to unpack .../43-python3-skimage-lib_0.16.2-2ubuntu1_amd64.deb ...
# Unpacking python3-skimage-lib:amd64 (0.16.2-2ubuntu1) ...
# Selecting previously unselected package python3-imageio.
# Preparing to unpack .../44-python3-imageio_2.4.1-3_all.deb ...
# Unpacking python3-imageio (2.4.1-3) ...
# Selecting previously unselected package python3-pywt.
# Preparing to unpack .../45-python3-pywt_0.5.1-1.3build1_amd64.deb ...
# Unpacking python3-pywt (0.5.1-1.3build1) ...
# Selecting previously unselected package python3-skimage.
# Preparing to unpack .../46-python3-skimage_0.16.2-2ubuntu1_all.deb ...
# Unpacking python3-skimage (0.16.2-2ubuntu1) ...
# Selecting previously unselected package python3-caffe-cpu.
# Preparing to unpack .../47-python3-caffe-cpu_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking python3-caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package caffe-cpu.
# Preparing to unpack .../48-caffe-cpu_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../49-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libblosc1.
# Preparing to unpack .../50-libblosc1_1.17.1+ds1-1_amd64.deb ...
# Unpacking libblosc1 (1.17.1+ds1-1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../51-liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package python-tables-data.
# Preparing to unpack .../52-python-tables-data_3.6.1-2build1_all.deb ...
# Unpacking python-tables-data (3.6.1-2build1) ...
# Selecting previously unselected package python3-atomicwrites.
# Preparing to unpack .../53-python3-atomicwrites_1.1.5-2build1_all.deb ...
# Unpacking python3-atomicwrites (1.1.5-2build1) ...
# Selecting previously unselected package python3-attr.
# Preparing to unpack .../54-python3-attr_19.3.0-2_all.deb ...
# Unpacking python3-attr (19.3.0-2) ...
# Selecting previously unselected package python3-blosc.
# Preparing to unpack .../55-python3-blosc_1.7.0+ds1-2ubuntu2_amd64.deb ...
# Unpacking python3-blosc (1.7.0+ds1-2ubuntu2) ...
# Selecting previously unselected package python3-soupsieve.
# Preparing to unpack .../56-python3-soupsieve_1.9.5+dfsg-1_all.deb ...
# Unpacking python3-soupsieve (1.9.5+dfsg-1) ...
# Selecting previously unselected package python3-bs4.
# Preparing to unpack .../57-python3-bs4_4.8.2-1_all.deb ...
# Unpacking python3-bs4 (4.8.2-1) ...
# Selecting previously unselected package python3-cloudpickle.
# Preparing to unpack .../58-python3-cloudpickle_1.3.0-1_all.deb ...
# Unpacking python3-cloudpickle (1.3.0-1) ...
# Selecting previously unselected package python3-fsspec.
# Preparing to unpack .../59-python3-fsspec_0.6.1-0.1_all.deb ...
# Unpacking python3-fsspec (0.6.1-0.1) ...
# Selecting previously unselected package python3-toolz.
# Preparing to unpack .../60-python3-toolz_0.9.0-1_all.deb ...
# Unpacking python3-toolz (0.9.0-1) ...
# Selecting previously unselected package python3-dask.
# Preparing to unpack .../61-python3-dask_2.8.1+dfsg-0.4_all.deb ...
# Unpacking python3-dask (2.8.1+dfsg-0.4) ...
# Selecting previously unselected package python3-et-xmlfile.
# Preparing to unpack .../62-python3-et-xmlfile_1.0.1-2.1_all.deb ...
# Unpacking python3-et-xmlfile (1.0.1-2.1) ...
# Selecting previously unselected package python3-webencodings.
# Preparing to unpack .../63-python3-webencodings_0.5.1-1ubuntu1_all.deb ...
# Unpacking python3-webencodings (0.5.1-1ubuntu1) ...
# Selecting previously unselected package python3-html5lib.
# Preparing to unpack .../64-python3-html5lib_1.0.1-2_all.deb ...
# Unpacking python3-html5lib (1.0.1-2) ...
# Selecting previously unselected package python3-more-itertools.
# Preparing to unpack .../65-python3-more-itertools_4.2.0-1build1_all.deb ...
# Unpacking python3-more-itertools (4.2.0-1build1) ...
# Selecting previously unselected package python3-zipp.
# Preparing to unpack .../66-python3-zipp_1.0.0-1_all.deb ...
# Unpacking python3-zipp (1.0.0-1) ...
# Selecting previously unselected package python3-importlib-metadata.
# Preparing to unpack .../67-python3-importlib-metadata_1.5.0-1_all.deb ...
# Unpacking python3-importlib-metadata (1.5.0-1) ...
# Selecting previously unselected package python3-jdcal.
# Preparing to unpack .../68-python3-jdcal_1.0-1.3_all.deb ...
# Unpacking python3-jdcal (1.0-1.3) ...
# Selecting previously unselected package python3-locket.
# Preparing to unpack .../69-python3-locket_0.2.0-1_all.deb ...
# Unpacking python3-locket (0.2.0-1) ...
# Selecting previously unselected package python3-lxml:amd64.
# Preparing to unpack .../70-python3-lxml_4.5.0-1ubuntu0.5_amd64.deb ...
# Unpacking python3-lxml:amd64 (4.5.0-1ubuntu0.5) ...
# Selecting previously unselected package python3-numexpr.
# Preparing to unpack .../71-python3-numexpr_2.7.1-1build1_amd64.deb ...
# Unpacking python3-numexpr (2.7.1-1build1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../72-python3-olefile_0.46-2_all.deb ...
# Unpacking python3-olefile (0.46-2) ...
# Selecting previously unselected package python3-openpyxl.
# Preparing to unpack .../73-python3-openpyxl_3.0.3-1_all.deb ...
# Unpacking python3-openpyxl (3.0.3-1) ...
# Selecting previously unselected package python3-packaging.
# Preparing to unpack .../74-python3-packaging_20.3-1_all.deb ...
# Unpacking python3-packaging (20.3-1) ...
# Selecting previously unselected package python3-partd.
# Preparing to unpack .../75-python3-partd_1.0.0-1_all.deb ...
# Unpacking python3-partd (1.0.0-1) ...
# Selecting previously unselected package python3-pluggy.
# Preparing to unpack .../76-python3-pluggy_0.13.0-2_all.deb ...
# Unpacking python3-pluggy (0.13.0-2) ...
# Selecting previously unselected package python3-py.
# Preparing to unpack .../77-python3-py_1.8.1-1ubuntu0.1_all.deb ...
# Unpacking python3-py (1.8.1-1ubuntu0.1) ...
# Selecting previously unselected package python3-pytest.
# Preparing to unpack .../78-python3-pytest_4.6.9-1_all.deb ...
# Unpacking python3-pytest (4.6.9-1) ...
# Selecting previously unselected package python3-tables-lib.
# Preparing to unpack .../79-python3-tables-lib_3.6.1-2build1_amd64.deb ...
# Unpacking python3-tables-lib (3.6.1-2build1) ...
# Selecting previously unselected package python3-tables.
# Preparing to unpack .../80-python3-tables_3.6.1-2build1_all.deb ...
# Unpacking python3-tables (3.6.1-2build1) ...
# Selecting previously unselected package python3-xlrd.
# Preparing to unpack .../81-python3-xlrd_1.1.0-5_all.deb ...
# Unpacking python3-xlrd (1.1.0-5) ...
# Selecting previously unselected package python3-xlwt.
# Preparing to unpack .../82-python3-xlwt_1.3.0-3_all.deb ...
# Unpacking python3-xlwt (1.3.0-3) ...
# Selecting previously unselected package python3-zmq.
# Preparing to unpack .../83-python3-zmq_18.1.1-3_amd64.deb ...
# Unpacking python3-zmq (18.1.1-3) ...
# Setting up python3-more-itertools (4.2.0-1build1) ...
# Setting up javascript-common (11) ...
# Setting up python3-attr (19.3.0-2) ...
# Setting up libleveldb1d:amd64 (1.22-3ubuntu2) ...
# Setting up ttf-bitstream-vera (1.10-8) ...
# Setting up python3-py (1.8.1-1ubuntu0.1) ...
# Setting up python3-jdcal (1.0-1.3) ...
# Setting up python3-backcall (0.1.0-2) ...
# Setting up python3-skimage-lib:amd64 (0.16.2-2ubuntu1) ...
# Setting up python3-parso (0.5.2-1ubuntu1) ...
# Setting up python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Setting up fonts-lyx (2.3.4.2-2) ...
# Setting up python3-olefile (0.46-2) ...
# Setting up python3-pandas-lib (0.25.3+dfsg-7) ...
# Setting up python3-fsspec (0.6.1-0.1) ...
# Setting up python3-yaml (5.3.1-1ubuntu0.1) ...
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up python3-zipp (1.0.0-1) ...
# Setting up python3-mpi4py (3.0.3-4build2) ...
# Setting up python3-nose (1.3.7-5) ...
# Setting up python3-webencodings (0.5.1-1ubuntu1) ...
# Setting up python3-tz (2019.3-1ubuntu0.20.04.0) ...
# Setting up python3-cloudpickle (1.3.0-1) ...
# Setting up python3-atomicwrites (1.1.5-2build1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Setting up python3-wcwidth (0.1.8+dfsg1-3) ...
# Setting up python3-pyparsing (2.4.6-1) ...
# Setting up python3-zmq (18.1.1-3) ...
# Setting up python3-cycler (0.10.0-3) ...
# Setting up libimagequant0:amd64 (2.12.2-1.1) ...
# Setting up python3-h5py (2.10.0-2build2) ...
# Setting up python3-kiwisolver (1.0.1-3build1) ...
# Setting up python3-xlwt (1.3.0-3) ...
# Setting up cython3 (0.29.14-0.1ubuntu3) ...
# Setting up python3-numexpr (2.7.1-1build1) ...
# Setting up python3-html5lib (1.0.1-2) ...
# Setting up python3-pickleshare (0.7.5-2) ...
# Setting up python3-lxml:amd64 (4.5.0-1ubuntu0.5) ...
# Setting up python3-traitlets (4.3.3-3) ...
# Setting up libblosc1 (1.17.1+ds1-1) ...
# Setting up python3-et-xmlfile (1.0.1-2.1) ...
# Setting up python3-xlrd (1.1.0-5) ...
# Setting up python3-toolz (0.9.0-1) ...
# Setting up python3-dateutil (2.7.3-3ubuntu1) ...
# Setting up python3-pywt (0.5.1-1.3build1) ...
# Setting up libjs-jquery (3.3.1~dfsg-3) ...
# Setting up python3-protobuf (3.6.1.3-2ubuntu5) ...
# Setting up python-matplotlib-data (3.1.2-1ubuntu4) ...
# Setting up python3-locket (0.2.0-1) ...
# Setting up python3-soupsieve (1.9.5+dfsg-1) ...
# Setting up python-tables-data (3.6.1-2build1) ...
# Setting up python3-gflags (1.5.1-7) ...
# Setting up liblbfgsb0:amd64 (3.0+dfsg.3-7build1) ...
# Setting up libgflags2.2 (2.2.2-1build1) ...
# Setting up python3-ptyprocess (0.6.0-1ubuntu1) ...
# Setting up python3-prompt-toolkit (2.0.10-2) ...
# Setting up python3-partd (1.0.0-1) ...
# Setting up python3-scipy (1.3.3-3build1) ...
# Setting up python3-importlib-metadata (1.5.0-1) ...
# Setting up python3-jedi (0.15.2-1) ...
# Setting up python3-tables-lib (3.6.1-2build1) ...
# Setting up python3-dask (2.8.1+dfsg-0.4) ...
# Setting up python3-tables (3.6.1-2build1) ...
# Setting up python3-networkx (2.4-3ubuntu1) ...
# /usr/lib/python3/dist-packages/networkx/readwrite/tests/test_graphml.py:933: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert H.nodes['n1']['special'] is 0
# /usr/lib/python3/dist-packages/networkx/readwrite/tests/test_graphml.py:935: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert H.edges['n0','n1',1]['special'] is 0
# Setting up python3-bs4 (4.8.2-1) ...
# Setting up python3-blosc (1.7.0+ds1-2ubuntu2) ...
# Setting up python3-pil:amd64 (7.0.0-4ubuntu0.7) ...
# Setting up python3-packaging (20.3-1) ...
# Setting up libjs-jquery-ui (1.12.1+dfsg-5) ...
# Setting up python3-pandas (0.25.3+dfsg-7) ...
# /usr/lib/python3/dist-packages/pandas/tests/frame/test_alter_axes.py:241: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   False if (keys[0] is "A" and keys[1] is "A") else drop  # noqa: F632
# /usr/lib/python3/dist-packages/pandas/tests/frame/test_alter_axes.py:241: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   False if (keys[0] is "A" and keys[1] is "A") else drop  # noqa: F632
# Setting up python3-openpyxl (3.0.3-1) ...
# Setting up python3-pexpect (4.6.0-1build1) ...
# Setting up python3-pluggy (0.13.0-2) ...
# Setting up libgoogle-glog0v5 (0.4.0-1build1) ...
# Setting up python3-imageio (2.4.1-3) ...
# /usr/lib/python3/dist-packages/imageio/plugins/_tifffile.py:2813: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 0:
# Setting up python3-matplotlib (3.1.2-1ubuntu4) ...
# Setting up libcaffe-cpu1:amd64 (1.0.0+git20180821.99bd997-5build3) ...
# Setting up python3-pytest (4.6.9-1) ...
# Setting up caffe-tools-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Setting up python3-ipython (7.13.0-1) ...
# Setting up python3-skimage (0.16.2-2ubuntu1) ...
# Setting up python3-caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Setting up caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...

# %%
pip install make
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting make
#   Downloading make-0.1.6.post2-py3-none-any.whl (14 kB)
# Collecting jinja2-time
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.8/dist-packages (from make) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2->make) (2.1.2)
# Collecting arrow
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.8/dist-packages (from arrow->jinja2-time->make) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.0->arrow->jinja2-time->make) (1.15.0)
# Installing collected packages: arrow, jinja2-time, make
# Successfully installed arrow-1.2.3 jinja2-time-0.2.0 make-0.1.6.post2

# %%
pip install cmake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cmake in /usr/local/lib/python3.8/dist-packages (3.22.6)

# %%
# !pip install protobuf==3.7.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting protobuf==3.7.1
#   Downloading protobuf-3.7.1-py2.py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.6/404.6 KB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from protobuf==3.7.1) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from protobuf==3.7.1) (57.4.0)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.7.1 which is incompatible.
# tensorflow-metadata 1.12.0 requires protobuf<4,>=3.13, but you have protobuf 3.7.1 which is incompatible.
# tensorflow-hub 0.12.0 requires protobuf>=3.8.0, but you have protobuf 3.7.1 which is incompatible.
# tensorflow-datasets 4.8.2 requires protobuf>=3.12.2, but you have protobuf 3.7.1 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 3.7.1 which is incompatible.
# proto-plus 1.22.2 requires protobuf<5.0.0dev,>=3.19.0, but you have protobuf 3.7.1 which is incompatible.
# grpcio-status 1.48.2 requires protobuf>=3.12.0, but you have protobuf 3.7.1 which is incompatible.
# googleapis-common-protos 1.58.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-cloud-translate 3.8.4 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-cloud-language 2.6.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-cloud-firestore 2.7.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-cloud-datastore 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-cloud-bigquery 3.4.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-cloud-bigquery-storage 2.18.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# google-api-core 2.11.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.7.1 which is incompatible.
# Successfully installed protobuf-3.7.1

# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (1.22.4)

# %%
import caffe

# %%
caffe.__version__
# Out:
# '1.0.0'

# %%
# !sudo apt-get install libprotobuf-dev protobuf-compiler
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.6.1.3-2ubuntu5).
# The following NEW packages will be installed:
#   libprotobuf-dev libprotobuf-lite17
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 1,287 kB of archives.
# After this operation, 11.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libprotobuf-lite17 amd64 3.6.1.3-2ubuntu5 [132 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libprotobuf-dev amd64 3.6.1.3-2ubuntu5 [1,155 kB]
# Fetched 1,287 kB in 1s (1,497 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libprotobuf-lite17:amd64.
# (Reading database ... 137279 files and directories currently installed.)
# Preparing to unpack .../libprotobuf-lite17_3.6.1.3-2ubuntu5_amd64.deb ...
# Unpacking libprotobuf-lite17:amd64 (3.6.1.3-2ubuntu5) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../libprotobuf-dev_3.6.1.3-2ubuntu5_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.6.1.3-2ubuntu5) ...
# Setting up libprotobuf-lite17:amd64 (3.6.1.3-2ubuntu5) ...
# Setting up libprotobuf-dev:amd64 (3.6.1.3-2ubuntu5) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
# !sudo apt-get install libopencv-dev python3-opencv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (4.2.0+dfsg-5+focal2).
# The following NEW packages will be installed:
#   python3-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 1,230 kB of archives.
# After this operation, 7,008 kB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 python3-opencv amd64 4.2.0+dfsg-5+focal2 [1,230 kB]
# Fetched 1,230 kB in 0s (10.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-opencv.
# (Reading database ... 137387 files and directories currently installed.)
# Preparing to unpack .../python3-opencv_4.2.0+dfsg-5+focal2_amd64.deb ...
# Unpacking python3-opencv (4.2.0+dfsg-5+focal2) ...
# Setting up python3-opencv (4.2.0+dfsg-5+focal2) ...

# %%
# !sudo apt-get install libopenblas-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopenblas-dev is already the newest version (0.3.8+ds-1ubuntu0.20.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# !sudo apt-get install libboost-all-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.71.0.0ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# !sudo apt-get install libprotobuf-dev libleveldb-dev libsnappy-dev libopencv-dev libhdf5-serial-dev protobuf-compiler
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libhdf5-dev' instead of 'libhdf5-serial-dev'
# libprotobuf-dev is already the newest version (3.6.1.3-2ubuntu5).
# libhdf5-dev is already the newest version (1.10.4+repack-11ubuntu1).
# protobuf-compiler is already the newest version (3.6.1.3-2ubuntu5).
# libopencv-dev is already the newest version (4.2.0+dfsg-5+focal2).
# Suggested packages:
#   leveldb-doc
# The following NEW packages will be installed:
#   libleveldb-dev libsnappy-dev
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 220 kB of archives.
# After this operation, 1,217 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libleveldb-dev amd64 1.22-3ubuntu2 [191 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libsnappy-dev amd64 1.1.8-1build1 [29.0 kB]
# Fetched 220 kB in 1s (373 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libleveldb-dev:amd64.
# (Reading database ... 137392 files and directories currently installed.)
# Preparing to unpack .../libleveldb-dev_1.22-3ubuntu2_amd64.deb ...
# Unpacking libleveldb-dev:amd64 (1.22-3ubuntu2) ...
# Selecting previously unselected package libsnappy-dev:amd64.
# Preparing to unpack .../libsnappy-dev_1.1.8-1build1_amd64.deb ...
# Unpacking libsnappy-dev:amd64 (1.1.8-1build1) ...
# Setting up libleveldb-dev:amd64 (1.22-3ubuntu2) ...
# Setting up libsnappy-dev:amd64 (1.1.8-1build1) ...

# %%
# !sudo apt-get install the python-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'python-dev-is-python2' instead of 'python-dev'
# The following additional packages will be installed:
#   libpython2-dev libpython2-stdlib libpython2.7 libpython2.7-dev libregina3
#   python-is-python2 python2 python2-dev python2-minimal python2.7-dev
# Suggested packages:
#   python2-doc python-tk the-doc
# The following NEW packages will be installed:
#   libpython2-dev libpython2-stdlib libpython2.7 libpython2.7-dev libregina3
#   python-dev-is-python2 python-is-python2 python2 python2-dev python2-minimal
#   python2.7-dev the
# 0 upgraded, 12 newly installed, 0 to remove and 19 not upgraded.
# Need to get 4,436 kB of archives.
# After this operation, 19.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libpython2.7 amd64 2.7.18-1~20.04.3 [1,037 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libpython2.7-dev amd64 2.7.18-1~20.04.3 [2,466 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-dev amd64 2.7.17-2ubuntu4 [7,140 B]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libregina3 amd64 3.6-2.1 [209 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-is-python2 all 2.7.17-4 [2,496 B]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python2.7-dev amd64 2.7.18-1~20.04.3 [293 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-dev amd64 2.7.17-2ubuntu4 [1,268 B]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-dev-is-python2 all 2.7.17-4 [1,396 B]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 the amd64 3.3~rc1-3build1 [357 kB]
# Fetched 4,436 kB in 2s (2,883 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 12.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python2-minimal.
# (Reading database ... 137439 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 137468 files and directories currently installed.)
# Preparing to unpack .../0-python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2.7:amd64.
# Preparing to unpack .../1-libpython2.7_2.7.18-1~20.04.3_amd64.deb ...
# Unpacking libpython2.7:amd64 (2.7.18-1~20.04.3) ...
# Selecting previously unselected package libpython2.7-dev:amd64.
# Preparing to unpack .../2-libpython2.7-dev_2.7.18-1~20.04.3_amd64.deb ...
# Unpacking libpython2.7-dev:amd64 (2.7.18-1~20.04.3) ...
# Selecting previously unselected package libpython2-dev:amd64.
# Preparing to unpack .../3-libpython2-dev_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-dev:amd64 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libregina3.
# Preparing to unpack .../4-libregina3_3.6-2.1_amd64.deb ...
# Unpacking libregina3 (3.6-2.1) ...
# Selecting previously unselected package python-is-python2.
# Preparing to unpack .../5-python-is-python2_2.7.17-4_all.deb ...
# Unpacking python-is-python2 (2.7.17-4) ...
# Selecting previously unselected package python2.7-dev.
# Preparing to unpack .../6-python2.7-dev_2.7.18-1~20.04.3_amd64.deb ...
# Unpacking python2.7-dev (2.7.18-1~20.04.3) ...
# Selecting previously unselected package python2-dev.
# Preparing to unpack .../7-python2-dev_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-dev (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python-dev-is-python2.
# Preparing to unpack .../8-python-dev-is-python2_2.7.17-4_all.deb ...
# Unpacking python-dev-is-python2 (2.7.17-4) ...
# Selecting previously unselected package the.
# Preparing to unpack .../9-the_3.3~rc1-3build1_amd64.deb ...
# Unpacking the (3.3~rc1-3build1) ...
# Setting up libpython2.7:amd64 (2.7.18-1~20.04.3) ...
# Setting up libpython2.7-dev:amd64 (2.7.18-1~20.04.3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up libpython2-dev:amd64 (2.7.17-2ubuntu4) ...
# Setting up libregina3 (3.6-2.1) ...
# Setting up python-is-python2 (2.7.17-4) ...
# Setting up python2.7-dev (2.7.18-1~20.04.3) ...
# Setting up python2-dev (2.7.17-2ubuntu4) ...
# Setting up the (3.3~rc1-3build1) ...
# Setting up python-dev-is-python2 (2.7.17-4) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
# !sudo apt-get install libgflags-dev libgoogle-glog-dev liblmdb-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   lmdb-doc
# The following NEW packages will be installed:
#   libgflags-dev libgoogle-glog-dev liblmdb-dev lmdb-doc
# 0 upgraded, 4 newly installed, 0 to remove and 19 not upgraded.
# Need to get 508 kB of archives.
# After this operation, 3,627 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgflags-dev amd64 2.2.2-1build1 [96.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgoogle-glog-dev amd64 0.4.0-1build1 [76.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 liblmdb-dev amd64 0.9.24-1 [59.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 lmdb-doc all 0.9.24-1 [275 kB]
# Fetched 508 kB in 1s (698 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgflags-dev.
# (Reading database ... 137704 files and directories currently installed.)
# Preparing to unpack .../libgflags-dev_2.2.2-1build1_amd64.deb ...
# Unpacking libgflags-dev (2.2.2-1build1) ...
# Selecting previously unselected package libgoogle-glog-dev.
# Preparing to unpack .../libgoogle-glog-dev_0.4.0-1build1_amd64.deb ...
# Unpacking libgoogle-glog-dev (0.4.0-1build1) ...
# Selecting previously unselected package liblmdb-dev:amd64.
# Preparing to unpack .../liblmdb-dev_0.9.24-1_amd64.deb ...
# Unpacking liblmdb-dev:amd64 (0.9.24-1) ...
# Selecting previously unselected package lmdb-doc.
# Preparing to unpack .../lmdb-doc_0.9.24-1_all.deb ...
# Unpacking lmdb-doc (0.9.24-1) ...
# Setting up lmdb-doc (0.9.24-1) ...
# Setting up libgflags-dev (2.2.2-1build1) ...
# Setting up liblmdb-dev:amd64 (0.9.24-1) ...
# Setting up libgoogle-glog-dev (0.4.0-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
import cv2
cv2.__version__
# Out:
# '4.6.0'

# %%
# !apt-get install python-numpy
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pkg-resources
# Suggested packages:
#   python-pytest python-numpy-dbg python-numpy-doc python-setuptools
# The following NEW packages will be installed:
#   python-numpy python-pkg-resources
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 2,274 kB of archives.
# After this operation, 12.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pkg-resources all 44.0.0-2ubuntu0.1 [130 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-numpy amd64 1:1.16.5-2ubuntu7 [2,144 kB]
# Fetched 2,274 kB in 1s (2,486 kB/s)
# Selecting previously unselected package python-pkg-resources.
# (Reading database ... 137960 files and directories currently installed.)
# Preparing to unpack .../python-pkg-resources_44.0.0-2ubuntu0.1_all.deb ...
# Unpacking python-pkg-resources (44.0.0-2ubuntu0.1) ...
# Selecting previously unselected package python-numpy.
# Preparing to unpack .../python-numpy_1%3a1.16.5-2ubuntu7_amd64.deb ...
# Unpacking python-numpy (1:1.16.5-2ubuntu7) ...
# Setting up python-pkg-resources (44.0.0-2ubuntu0.1) ...
# Setting up python-numpy (1:1.16.5-2ubuntu7) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !sudo ln -s /usr/include/opencv4/opencv2 /usr/include/opencv2

# %%
pip install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.8/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-contrib-python) (1.22.4)

# %% [markdown]
# **COMPILING TEXTBOX**

# %%
#!rm -rf ./build*/

# %%
#!make clean

# %%
#!make -j8

# %%
#!make py

# %% [markdown]
# **RUNNING DEMO**

# %%
#! python examples/TextBoxes/demo.py
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# F0302 06:30:31.778272 58940 common.cpp:151] Check failed: error == cudaSuccess (100 vs. 0)  no CUDA-capable device is detected
# *** Check failure stack trace: ***

# %% [markdown]
# **PREPARING TRAINING DATASET**

# %%
#! chmod 777 /content/drive/MyDrive/TextBoxes/build/tools/convert_annoset

# %%
#! bash ./data/text/create_data.sh

# %% [markdown]
# **TRAINING CUSTOM DATASET**

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/TextBoxes'

# %%
! chmod 777 ./build/tools/caffe

# %%
! python examples/TextBoxes/train_icdar13.py
# Out:
# Streaming output truncated to the last 5000 lines.
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3_1"
#   type: "ReLU"
#   bottom: "conv3_1"
#   top: "conv3_1"
# }
# layer {
#   name: "conv3_2"
#   type: "Convolution"
#   bottom: "conv3_1"
#   top: "conv3_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3_2"
#   type: "ReLU"
#   bottom: "conv3_2"
#   top: "conv3_2"
# }
# layer {
#   name: "conv3_3"
#   type: "Convolution"
#   bottom: "conv3_2"
#   top: "conv3_3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3_3"
#   type: "ReLU"
#   bottom: "conv3_3"
#   top: "conv3_3"
# }
# layer {
#   name: "pool3"
#   type: "Pooling"
#   bottom: "conv3_3"
#   top: "pool3"
#   pooling_param {
#     pool: MAX
#     kernel_size: 2
#     stride: 2
#   }
# }
# layer {
#   name: "conv4_1"
#   type: "Convolution"
#   bottom: "pool3"
#   top: "conv4_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu4_1"
#   type: "ReLU"
#   bottom: "conv4_1"
#   top: "conv4_1"
# }
# layer {
#   name: "conv4_2"
#   type: "Convolution"
#   bottom: "conv4_1"
#   top: "conv4_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu4_2"
#   type: "ReLU"
#   bottom: "conv4_2"
#   top: "conv4_2"
# }
# layer {
#   name: "conv4_3"
#   type: "Convolution"
#   bottom: "conv4_2"
#   top: "conv4_3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu4_3"
#   type: "ReLU"
#   bottom: "conv4_3"
#   top: "conv4_3"
# }
# layer {
#   name: "pool4"
#   type: "Pooling"
#   bottom: "conv4_3"
#   top: "pool4"
#   pooling_param {
#     pool: MAX
#     kernel_size: 2
#     stride: 2
#   }
# }
# layer {
#   name: "conv5_1"
#   type: "Convolution"
#   bottom: "pool4"
#   top: "conv5_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu5_1"
#   type: "ReLU"
#   bottom: "conv5_1"
#   top: "conv5_1"
# }
# layer {
#   name: "conv5_2"
#   type: "Convolution"
#   bottom: "conv5_1"
#   top: "conv5_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu5_2"
#   type: "ReLU"
#   bottom: "conv5_2"
#   top: "conv5_2"
# }
# layer {
#   name: "conv5_3"
#   type: "Convolution"
#   bottom: "conv5_2"
#   top: "conv5_3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu5_3"
#   type: "ReLU"
#   bottom: "conv5_3"
#   top: "conv5_3"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5_3"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "fc6"
#   type: "Convolution"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 1024
#     pad: 6
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     dilation: 6
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "fc7"
#   type: "Convolution"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 1024
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "conv6_1"
#   type: "Convolution"
#   bottom: "fc7"
#   top: "conv6_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 0
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv6_1_relu"
#   type: "ReLU"
#   bottom: "conv6_1"
#   top: "conv6_1"
# }
# layer {
#   name: "conv6_2"
#   type: "Convolution"
#   bottom: "conv6_1"
#   top: "conv6_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 2
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv6_2_relu"
#   type: "ReLU"
#   bottom: "conv6_2"
#   top: "conv6_2"
# }
# layer {
#   name: "conv7_1"
#   type: "Convolution"
#   bottom: "conv6_2"
#   top: "conv7_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 0
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv7_1_relu"
#   type: "ReLU"
#   bottom: "conv7_1"
#   top: "conv7_1"
# }
# layer {
#   name: "conv7_2"
#   type: "Convolution"
#   bottom: "conv7_1"
#   top: "conv7_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 2
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv7_2_relu"
#   type: "ReLU"
#   bottom: "conv7_2"
#   top: "conv7_2"
# }
# layer {
#   name: "conv8_1"
#   type: "Convolution"
#   bottom: "conv7_2"
#   top: "conv8_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 0
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv8_1_relu"
#   type: "ReLU"
#   bottom: "conv8_1"
#   top: "conv8_1"
# }
# layer {
#   name: "conv8_2"
#   type: "Convolution"
#   bottom: "conv8_1"
#   top: "conv8_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 2
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv8_2_relu"
#   type: "ReLU"
#   bottom: "conv8_2"
#   top: "conv8_2"
# }
# layer {
#   name: "pool6"
#   type: "Pooling"
#   bottom: "conv8_2"
#   top: "pool6"
#   pooling_param {
#     pool: AVE
#     global_pooling: true
#   }
# }
# layer {
#   name: "conv4_3_norm"
#   type: "Normalize"
#   bottom: "conv4_3"
#   top: "conv4_3_norm"
#   norm_param {
#     across_spatial: false
#     scale_filler {
#       type: "constant"
#       value: 20
#     }
#     channel_shared: false
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_loc"
#   type: "Convolution"
#   bottom: "conv4_3_norm"
#   top: "conv4_3_norm_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 48
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv4_3_norm_mbox_loc"
#   top: "conv4_3_norm_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv4_3_norm_mbox_loc_perm"
#   top: "conv4_3_norm_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_conf"
#   type: "Convolution"
#   bottom: "conv4_3_norm"
#   top: "conv4_3_norm_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 24
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv4_3_norm_mbox_conf"
#   top: "conv4_3_norm_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv4_3_norm_mbox_conf_perm"
#   top: "conv4_3_norm_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv4_3_norm"
#   bottom: "data"
#   top: "conv4_3_norm_mbox_priorbox"
#   prior_box_param {
#     min_size: 30
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "fc7_mbox_loc"
#   type: "Convolution"
#   bottom: "fc7"
#   top: "fc7_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "fc7_mbox_loc_perm"
#   type: "Permute"
#   bottom: "fc7_mbox_loc"
#   top: "fc7_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "fc7_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "fc7_mbox_loc_perm"
#   top: "fc7_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "fc7_mbox_conf"
#   type: "Convolution"
#   bottom: "fc7"
#   top: "fc7_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "fc7_mbox_conf_perm"
#   type: "Permute"
#   bottom: "fc7_mbox_conf"
#   top: "fc7_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "fc7_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "fc7_mbox_conf_perm"
#   top: "fc7_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "fc7_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "fc7"
#   bottom: "data"
#   top: "fc7_mbox_priorbox"
#   prior_box_param {
#     min_size: 60
#     max_size: 114
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "conv6_2_mbox_loc"
#   type: "Convolution"
#   bottom: "conv6_2"
#   top: "conv6_2_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv6_2_mbox_loc"
#   top: "conv6_2_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv6_2_mbox_loc_perm"
#   top: "conv6_2_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_conf"
#   type: "Convolution"
#   bottom: "conv6_2"
#   top: "conv6_2_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv6_2_mbox_conf"
#   top: "conv6_2_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv6_2_mbox_conf_perm"
#   top: "conv6_2_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv6_2"
#   bottom: "data"
#   top: "conv6_2_mbox_priorbox"
#   prior_box_param {
#     min_size: 114
#     max_size: 168
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "conv7_2_mbox_loc"
#   type: "Convolution"
#   bottom: "conv7_2"
#   top: "conv7_2_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv7_2_mbox_loc"
#   top: "conv7_2_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv7_2_mbox_loc_perm"
#   top: "conv7_2_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_conf"
#   type: "Convolution"
#   bottom: "conv7_2"
#   top: "conv7_2_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv7_2_mbox_conf"
#   top: "conv7_2_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv7_2_mbox_conf_perm"
#   top: "conv7_2_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv7_2"
#   bottom: "data"
#   top: "conv7_2_mbox_priorbox"
#   prior_box_param {
#     min_size: 168
#     max_size: 222
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "conv8_2_mbox_loc"
#   type: "Convolution"
#   bottom: "conv8_2"
#   top: "conv8_2_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv8_2_mbox_loc"
#   top: "conv8_2_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv8_2_mbox_loc_perm"
#   top: "conv8_2_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_conf"
#   type: "Convolution"
#   bottom: "conv8_2"
#   top: "conv8_2_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv8_2_mbox_conf"
#   top: "conv8_2_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv8_2_mbox_conf_perm"
#   top: "conv8_2_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv8_2"
#   bottom: "data"
#   top: "conv8_2_mbox_priorbox"
#   prior_box_param {
#     min_size: 222
#     max_size: 276
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "pool6_mbox_loc"
#   type: "Convolution"
#   bottom: "pool6"
#   top: "pool6_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "pool6_mbox_loc_perm"
#   type: "Permute"
#   bottom: "pool6_mbox_loc"
#   top: "pool6_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "pool6_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "pool6_mbox_loc_perm"
#   top: "pool6_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "pool6_mbox_conf"
#   type: "Convolution"
#   bottom: "pool6"
#   top: "pool6_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "pool6_mbox_conf_perm"
#   type: "Permute"
#   bottom: "pool6_mbox_conf"
#   top: "pool6_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "pool6_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "pool6_mbox_conf_perm"
#   top: "pool6_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "pool6_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "pool6"
#   bottom: "data"
#   top: "pool6_mbox_priorbox"
#   prior_box_param {
#     min_size: 276
#     max_size: 330
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "mbox_loc"
#   type: "Concat"
#   bottom: "conv4_3_norm_mbox_loc_flat"
#   bottom: "fc7_mbox_loc_flat"
#   bottom: "conv6_2_mbox_loc_flat"
#   bottom: "conv7_2_mbox_loc_flat"
#   bottom: "conv8_2_mbox_loc_flat"
#   bottom: "pool6_mbox_loc_flat"
#   top: "mbox_loc"
#   concat_param {
#     axis: 1
#   }
# }
# layer {
#   name: "mbox_conf"
#   type: "Concat"
#   bottom: "conv4_3_norm_mbox_conf_flat"
#   bottom: "fc7_mbox_conf_flat"
#   bottom: "conv6_2_mbox_conf_flat"
#   bottom: "conv7_2_mbox_conf_flat"
#   bottom: "conv8_2_mbox_conf_flat"
#   bottom: "pool6_mbox_conf_flat"
#   top: "mbox_conf"
#   concat_param {
#     axis: 1
#   }
# }
# layer {
#   name: "mbox_priorbox"
#   type: "Concat"
#   bottom: "conv4_3_norm_mbox_priorbox"
#   bottom: "fc7_mbox_priorbox"
#   bottom: "conv6_2_mbox_priorbox"
#   bottom: "conv7_2_mbox_priorbox"
#   bottom: "conv8_2_mbox_priorbox"
#   bottom: "pool6_mbox_priorbox"
#   top: "mbox_priorbox"
#   concat_param {
#     axis: 2
#   }
# }
# layer {
#   name: "mbox_loss"
#   type: "MultiBoxLoss"
#   bottom: "mbox_loc"
#   bottom: "mbox_conf"
#   bottom: "mbox_priorbox"
#   bottom: "label"
#   top: "mbox_loss"
#   include {
#     phase: TRAIN
#   }
#   propagate_down: true
#   propagate_down: true
#   propagate_down: false
#   propagate_down: false
#   loss_param {
#     normalization: VALID
#   }
#   multibox_loss_param {
#     loc_loss_type: SMOOTH_L1
#     conf_loss_type: SOFTMAX
#     loc_weight: 1
#     num_classes: 2
#     share_location: true
#     match_type: PER_PREDICTION
#     overlap_threshold: 0.5
#     use_prior_for_matching: true
#     background_label_id: 0
#     use_difficult_gt: true
#     do_neg_mining: true
#     neg_pos_ratio: 3
#     neg_overlap: 0.5
#     code_type: CENTER_SIZE
#   }
# }
# I0302 07:57:42.604369  7434 layer_factory.hpp:77] Creating layer data
# I0302 07:57:42.605212  7434 net.cpp:100] Creating Layer data
# I0302 07:57:42.605234  7434 net.cpp:408] data -> data
# I0302 07:57:42.605283  7434 net.cpp:408] data -> label
# I0302 07:57:42.608160  7443 db_lmdb.cpp:35] Opened lmdb data/lmdb/lmdb/text_train_lmdb
# I0302 07:57:42.799222  7434 annotated_data_layer.cpp:52] output data size: 32,3,300,300
# I0302 07:57:42.866001  7434 net.cpp:150] Setting up data
# I0302 07:57:42.866072  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.866084  7434 net.cpp:157] Top shape: 1 1 17 8 (136)
# I0302 07:57:42.866089  7434 net.cpp:165] Memory required for data: 34560544
# I0302 07:57:42.866103  7434 layer_factory.hpp:77] Creating layer data_data_0_split
# I0302 07:57:42.866318  7434 net.cpp:100] Creating Layer data_data_0_split
# I0302 07:57:42.866348  7434 net.cpp:434] data_data_0_split <- data
# I0302 07:57:42.866411  7434 net.cpp:408] data_data_0_split -> data_data_0_split_0
# I0302 07:57:42.866429  7434 net.cpp:408] data_data_0_split -> data_data_0_split_1
# I0302 07:57:42.866458  7434 net.cpp:408] data_data_0_split -> data_data_0_split_2
# I0302 07:57:42.866473  7434 net.cpp:408] data_data_0_split -> data_data_0_split_3
# I0302 07:57:42.866539  7434 net.cpp:408] data_data_0_split -> data_data_0_split_4
# I0302 07:57:42.866549  7434 net.cpp:408] data_data_0_split -> data_data_0_split_5
# I0302 07:57:42.866569  7434 net.cpp:408] data_data_0_split -> data_data_0_split_6
# I0302 07:57:42.867043  7434 net.cpp:150] Setting up data_data_0_split
# I0302 07:57:42.867081  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867090  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867094  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867098  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867103  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867121  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867126  7434 net.cpp:157] Top shape: 32 3 300 300 (8640000)
# I0302 07:57:42.867130  7434 net.cpp:165] Memory required for data: 276480544
# I0302 07:57:42.867136  7434 layer_factory.hpp:77] Creating layer conv1_1
# I0302 07:57:42.867216  7434 net.cpp:100] Creating Layer conv1_1
# I0302 07:57:42.867223  7434 net.cpp:434] conv1_1 <- data_data_0_split_0
# I0302 07:57:42.867233  7434 net.cpp:408] conv1_1 -> conv1_1
# I0302 07:57:42.869061  7434 net.cpp:150] Setting up conv1_1
# I0302 07:57:42.869211  7434 net.cpp:157] Top shape: 32 64 300 300 (184320000)
# I0302 07:57:42.869289  7434 net.cpp:165] Memory required for data: 1013760544
# I0302 07:57:42.869374  7434 layer_factory.hpp:77] Creating layer relu1_1
# I0302 07:57:42.869462  7434 net.cpp:100] Creating Layer relu1_1
# I0302 07:57:42.869529  7434 net.cpp:434] relu1_1 <- conv1_1
# I0302 07:57:42.869596  7434 net.cpp:395] relu1_1 -> conv1_1 (in-place)
# I0302 07:57:42.869899  7434 net.cpp:150] Setting up relu1_1
# I0302 07:57:42.870003  7434 net.cpp:157] Top shape: 32 64 300 300 (184320000)
# I0302 07:57:42.870079  7434 net.cpp:165] Memory required for data: 1751040544
# I0302 07:57:42.870151  7434 layer_factory.hpp:77] Creating layer conv1_2
# I0302 07:57:42.870227  7434 net.cpp:100] Creating Layer conv1_2
# I0302 07:57:42.870293  7434 net.cpp:434] conv1_2 <- conv1_1
# I0302 07:57:42.870362  7434 net.cpp:408] conv1_2 -> conv1_2
# I0302 07:57:42.871075  7434 net.cpp:150] Setting up conv1_2
# I0302 07:57:42.871207  7434 net.cpp:157] Top shape: 32 64 300 300 (184320000)
# I0302 07:57:42.871282  7434 net.cpp:165] Memory required for data: 2488320544
# I0302 07:57:42.871354  7434 layer_factory.hpp:77] Creating layer relu1_2
# I0302 07:57:42.871435  7434 net.cpp:100] Creating Layer relu1_2
# I0302 07:57:42.871502  7434 net.cpp:434] relu1_2 <- conv1_2
# I0302 07:57:42.871569  7434 net.cpp:395] relu1_2 -> conv1_2 (in-place)
# I0302 07:57:42.871634  7434 net.cpp:150] Setting up relu1_2
# I0302 07:57:42.871696  7434 net.cpp:157] Top shape: 32 64 300 300 (184320000)
# I0302 07:57:42.871762  7434 net.cpp:165] Memory required for data: 3225600544
# I0302 07:57:42.871815  7434 layer_factory.hpp:77] Creating layer pool1
# I0302 07:57:42.871874  7434 net.cpp:100] Creating Layer pool1
# I0302 07:57:42.871927  7434 net.cpp:434] pool1 <- conv1_2
# I0302 07:57:42.871981  7434 net.cpp:408] pool1 -> pool1
# I0302 07:57:42.872085  7434 net.cpp:150] Setting up pool1
# I0302 07:57:42.872152  7434 net.cpp:157] Top shape: 32 64 150 150 (46080000)
# I0302 07:57:42.872208  7434 net.cpp:165] Memory required for data: 3409920544
# I0302 07:57:42.872260  7434 layer_factory.hpp:77] Creating layer conv2_1
# I0302 07:57:42.872321  7434 net.cpp:100] Creating Layer conv2_1
# I0302 07:57:42.872377  7434 net.cpp:434] conv2_1 <- pool1
# I0302 07:57:42.872447  7434 net.cpp:408] conv2_1 -> conv2_1
# I0302 07:57:42.873378  7434 net.cpp:150] Setting up conv2_1
# I0302 07:57:42.873486  7434 net.cpp:157] Top shape: 32 128 150 150 (92160000)
# I0302 07:57:42.873548  7434 net.cpp:165] Memory required for data: 3778560544
# I0302 07:57:42.873605  7434 layer_factory.hpp:77] Creating layer relu2_1
# I0302 07:57:42.873663  7434 net.cpp:100] Creating Layer relu2_1
# I0302 07:57:42.873718  7434 net.cpp:434] relu2_1 <- conv2_1
# I0302 07:57:42.873772  7434 net.cpp:395] relu2_1 -> conv2_1 (in-place)
# I0302 07:57:42.873852  7434 net.cpp:150] Setting up relu2_1
# I0302 07:57:42.873937  7434 net.cpp:157] Top shape: 32 128 150 150 (92160000)
# I0302 07:57:42.873996  7434 net.cpp:165] Memory required for data: 4147200544
# I0302 07:57:42.874049  7434 layer_factory.hpp:77] Creating layer conv2_2
# I0302 07:57:42.874111  7434 net.cpp:100] Creating Layer conv2_2
# I0302 07:57:42.874176  7434 net.cpp:434] conv2_2 <- conv2_1
# I0302 07:57:42.874235  7434 net.cpp:408] conv2_2 -> conv2_2
# I0302 07:57:42.875850  7434 net.cpp:150] Setting up conv2_2
# I0302 07:57:42.875953  7434 net.cpp:157] Top shape: 32 128 150 150 (92160000)
# I0302 07:57:42.876014  7434 net.cpp:165] Memory required for data: 4515840544
# I0302 07:57:42.876072  7434 layer_factory.hpp:77] Creating layer relu2_2
# I0302 07:57:42.876128  7434 net.cpp:100] Creating Layer relu2_2
# I0302 07:57:42.876188  7434 net.cpp:434] relu2_2 <- conv2_2
# I0302 07:57:42.876242  7434 net.cpp:395] relu2_2 -> conv2_2 (in-place)
# I0302 07:57:42.876300  7434 net.cpp:150] Setting up relu2_2
# I0302 07:57:42.876356  7434 net.cpp:157] Top shape: 32 128 150 150 (92160000)
# I0302 07:57:42.876423  7434 net.cpp:165] Memory required for data: 4884480544
# I0302 07:57:42.876480  7434 layer_factory.hpp:77] Creating layer pool2
# I0302 07:57:42.876538  7434 net.cpp:100] Creating Layer pool2
# I0302 07:57:42.876591  7434 net.cpp:434] pool2 <- conv2_2
# I0302 07:57:42.876646  7434 net.cpp:408] pool2 -> pool2
# I0302 07:57:42.876736  7434 net.cpp:150] Setting up pool2
# I0302 07:57:42.876794  7434 net.cpp:157] Top shape: 32 128 75 75 (23040000)
# I0302 07:57:42.876849  7434 net.cpp:165] Memory required for data: 4976640544
# I0302 07:57:42.876900  7434 layer_factory.hpp:77] Creating layer conv3_1
# I0302 07:57:42.876960  7434 net.cpp:100] Creating Layer conv3_1
# I0302 07:57:42.877010  7434 net.cpp:434] conv3_1 <- pool2
# I0302 07:57:42.877066  7434 net.cpp:408] conv3_1 -> conv3_1
# I0302 07:57:42.881209  7434 net.cpp:150] Setting up conv3_1
# I0302 07:57:42.881321  7434 net.cpp:157] Top shape: 32 256 75 75 (46080000)
# I0302 07:57:42.881384  7434 net.cpp:165] Memory required for data: 5160960544
# I0302 07:57:42.881466  7434 layer_factory.hpp:77] Creating layer relu3_1
# I0302 07:57:42.881525  7434 net.cpp:100] Creating Layer relu3_1
# I0302 07:57:42.881577  7434 net.cpp:434] relu3_1 <- conv3_1
# I0302 07:57:42.881635  7434 net.cpp:395] relu3_1 -> conv3_1 (in-place)
# I0302 07:57:42.881697  7434 net.cpp:150] Setting up relu3_1
# I0302 07:57:42.881752  7434 net.cpp:157] Top shape: 32 256 75 75 (46080000)
# I0302 07:57:42.881808  7434 net.cpp:165] Memory required for data: 5345280544
# I0302 07:57:42.881863  7434 layer_factory.hpp:77] Creating layer conv3_2
# I0302 07:57:42.881923  7434 net.cpp:100] Creating Layer conv3_2
# I0302 07:57:42.881976  7434 net.cpp:434] conv3_2 <- conv3_1
# I0302 07:57:42.882031  7434 net.cpp:408] conv3_2 -> conv3_2
# I0302 07:57:42.889202  7434 net.cpp:150] Setting up conv3_2
# I0302 07:57:42.889325  7434 net.cpp:157] Top shape: 32 256 75 75 (46080000)
# I0302 07:57:42.889400  7434 net.cpp:165] Memory required for data: 5529600544
# I0302 07:57:42.889463  7434 layer_factory.hpp:77] Creating layer relu3_2
# I0302 07:57:42.889521  7434 net.cpp:100] Creating Layer relu3_2
# I0302 07:57:42.889575  7434 net.cpp:434] relu3_2 <- conv3_2
# I0302 07:57:42.889629  7434 net.cpp:395] relu3_2 -> conv3_2 (in-place)
# I0302 07:57:42.889693  7434 net.cpp:150] Setting up relu3_2
# I0302 07:57:42.889750  7434 net.cpp:157] Top shape: 32 256 75 75 (46080000)
# I0302 07:57:42.889806  7434 net.cpp:165] Memory required for data: 5713920544
# I0302 07:57:42.889860  7434 layer_factory.hpp:77] Creating layer conv3_3
# I0302 07:57:42.889923  7434 net.cpp:100] Creating Layer conv3_3
# I0302 07:57:42.889977  7434 net.cpp:434] conv3_3 <- conv3_2
# I0302 07:57:42.890033  7434 net.cpp:408] conv3_3 -> conv3_3
# I0302 07:57:42.896930  7434 net.cpp:150] Setting up conv3_3
# I0302 07:57:42.897043  7434 net.cpp:157] Top shape: 32 256 75 75 (46080000)
# I0302 07:57:42.897106  7434 net.cpp:165] Memory required for data: 5898240544
# I0302 07:57:42.897173  7434 layer_factory.hpp:77] Creating layer relu3_3
# I0302 07:57:42.897254  7434 net.cpp:100] Creating Layer relu3_3
# I0302 07:57:42.897336  7434 net.cpp:434] relu3_3 <- conv3_3
# I0302 07:57:42.897404  7434 net.cpp:395] relu3_3 -> conv3_3 (in-place)
# I0302 07:57:42.897469  7434 net.cpp:150] Setting up relu3_3
# I0302 07:57:42.897524  7434 net.cpp:157] Top shape: 32 256 75 75 (46080000)
# I0302 07:57:42.897581  7434 net.cpp:165] Memory required for data: 6082560544
# I0302 07:57:42.897636  7434 layer_factory.hpp:77] Creating layer pool3
# I0302 07:57:42.897693  7434 net.cpp:100] Creating Layer pool3
# I0302 07:57:42.897745  7434 net.cpp:434] pool3 <- conv3_3
# I0302 07:57:42.897800  7434 net.cpp:408] pool3 -> pool3
# I0302 07:57:42.897890  7434 net.cpp:150] Setting up pool3
# I0302 07:57:42.897948  7434 net.cpp:157] Top shape: 32 256 38 38 (11829248)
# I0302 07:57:42.898002  7434 net.cpp:165] Memory required for data: 6129877536
# I0302 07:57:42.898057  7434 layer_factory.hpp:77] Creating layer conv4_1
# I0302 07:57:42.898114  7434 net.cpp:100] Creating Layer conv4_1
# I0302 07:57:42.898173  7434 net.cpp:434] conv4_1 <- pool3
# I0302 07:57:42.898231  7434 net.cpp:408] conv4_1 -> conv4_1
# I0302 07:57:42.911582  7434 net.cpp:150] Setting up conv4_1
# I0302 07:57:42.911700  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.911767  7434 net.cpp:165] Memory required for data: 6224511520
# I0302 07:57:42.911826  7434 layer_factory.hpp:77] Creating layer relu4_1
# I0302 07:57:42.911883  7434 net.cpp:100] Creating Layer relu4_1
# I0302 07:57:42.911936  7434 net.cpp:434] relu4_1 <- conv4_1
# I0302 07:57:42.911990  7434 net.cpp:395] relu4_1 -> conv4_1 (in-place)
# I0302 07:57:42.912046  7434 net.cpp:150] Setting up relu4_1
# I0302 07:57:42.912099  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.912160  7434 net.cpp:165] Memory required for data: 6319145504
# I0302 07:57:42.912212  7434 layer_factory.hpp:77] Creating layer conv4_2
# I0302 07:57:42.912294  7434 net.cpp:100] Creating Layer conv4_2
# I0302 07:57:42.912393  7434 net.cpp:434] conv4_2 <- conv4_1
# I0302 07:57:42.912473  7434 net.cpp:408] conv4_2 -> conv4_2
# I0302 07:57:42.940735  7434 net.cpp:150] Setting up conv4_2
# I0302 07:57:42.940862  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.940932  7434 net.cpp:165] Memory required for data: 6413779488
# I0302 07:57:42.940999  7434 layer_factory.hpp:77] Creating layer relu4_2
# I0302 07:57:42.941059  7434 net.cpp:100] Creating Layer relu4_2
# I0302 07:57:42.941116  7434 net.cpp:434] relu4_2 <- conv4_2
# I0302 07:57:42.941188  7434 net.cpp:395] relu4_2 -> conv4_2 (in-place)
# I0302 07:57:42.941246  7434 net.cpp:150] Setting up relu4_2
# I0302 07:57:42.941300  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.941354  7434 net.cpp:165] Memory required for data: 6508413472
# I0302 07:57:42.941418  7434 layer_factory.hpp:77] Creating layer conv4_3
# I0302 07:57:42.941479  7434 net.cpp:100] Creating Layer conv4_3
# I0302 07:57:42.941532  7434 net.cpp:434] conv4_3 <- conv4_2
# I0302 07:57:42.941588  7434 net.cpp:408] conv4_3 -> conv4_3
# I0302 07:57:42.984967  7434 net.cpp:150] Setting up conv4_3
# I0302 07:57:42.985126  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.985216  7434 net.cpp:165] Memory required for data: 6603047456
# I0302 07:57:42.985280  7434 layer_factory.hpp:77] Creating layer relu4_3
# I0302 07:57:42.985337  7434 net.cpp:100] Creating Layer relu4_3
# I0302 07:57:42.985402  7434 net.cpp:434] relu4_3 <- conv4_3
# I0302 07:57:42.985462  7434 net.cpp:395] relu4_3 -> conv4_3 (in-place)
# I0302 07:57:42.985523  7434 net.cpp:150] Setting up relu4_3
# I0302 07:57:42.985576  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.985633  7434 net.cpp:165] Memory required for data: 6697681440
# I0302 07:57:42.985692  7434 layer_factory.hpp:77] Creating layer conv4_3_relu4_3_0_split
# I0302 07:57:42.985752  7434 net.cpp:100] Creating Layer conv4_3_relu4_3_0_split
# I0302 07:57:42.985808  7434 net.cpp:434] conv4_3_relu4_3_0_split <- conv4_3
# I0302 07:57:42.985868  7434 net.cpp:408] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_0
# I0302 07:57:42.985930  7434 net.cpp:408] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_1
# I0302 07:57:42.986083  7434 net.cpp:150] Setting up conv4_3_relu4_3_0_split
# I0302 07:57:42.986145  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.986330  7434 net.cpp:157] Top shape: 32 512 38 38 (23658496)
# I0302 07:57:42.986402  7434 net.cpp:165] Memory required for data: 6886949408
# I0302 07:57:42.986460  7434 layer_factory.hpp:77] Creating layer pool4
# I0302 07:57:42.986522  7434 net.cpp:100] Creating Layer pool4
# I0302 07:57:42.986580  7434 net.cpp:434] pool4 <- conv4_3_relu4_3_0_split_0
# I0302 07:57:42.986639  7434 net.cpp:408] pool4 -> pool4
# I0302 07:57:42.986744  7434 net.cpp:150] Setting up pool4
# I0302 07:57:42.986809  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:42.986865  7434 net.cpp:165] Memory required for data: 6910607904
# I0302 07:57:42.986917  7434 layer_factory.hpp:77] Creating layer conv5_1
# I0302 07:57:42.986979  7434 net.cpp:100] Creating Layer conv5_1
# I0302 07:57:42.987030  7434 net.cpp:434] conv5_1 <- pool4
# I0302 07:57:42.987087  7434 net.cpp:408] conv5_1 -> conv5_1
# I0302 07:57:43.013815  7434 net.cpp:150] Setting up conv5_1
# I0302 07:57:43.013957  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.014026  7434 net.cpp:165] Memory required for data: 6934266400
# I0302 07:57:43.014091  7434 layer_factory.hpp:77] Creating layer relu5_1
# I0302 07:57:43.014158  7434 net.cpp:100] Creating Layer relu5_1
# I0302 07:57:43.014216  7434 net.cpp:434] relu5_1 <- conv5_1
# I0302 07:57:43.014272  7434 net.cpp:395] relu5_1 -> conv5_1 (in-place)
# I0302 07:57:43.014330  7434 net.cpp:150] Setting up relu5_1
# I0302 07:57:43.014384  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.014451  7434 net.cpp:165] Memory required for data: 6957924896
# I0302 07:57:43.014503  7434 layer_factory.hpp:77] Creating layer conv5_2
# I0302 07:57:43.014562  7434 net.cpp:100] Creating Layer conv5_2
# I0302 07:57:43.014616  7434 net.cpp:434] conv5_2 <- conv5_1
# I0302 07:57:43.014672  7434 net.cpp:408] conv5_2 -> conv5_2
# I0302 07:57:43.049842  7434 net.cpp:150] Setting up conv5_2
# I0302 07:57:43.049983  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.050052  7434 net.cpp:165] Memory required for data: 6981583392
# I0302 07:57:43.050117  7434 layer_factory.hpp:77] Creating layer relu5_2
# I0302 07:57:43.050186  7434 net.cpp:100] Creating Layer relu5_2
# I0302 07:57:43.050246  7434 net.cpp:434] relu5_2 <- conv5_2
# I0302 07:57:43.050307  7434 net.cpp:395] relu5_2 -> conv5_2 (in-place)
# I0302 07:57:43.050366  7434 net.cpp:150] Setting up relu5_2
# I0302 07:57:43.050432  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.050488  7434 net.cpp:165] Memory required for data: 7005241888
# I0302 07:57:43.050542  7434 layer_factory.hpp:77] Creating layer conv5_3
# I0302 07:57:43.050601  7434 net.cpp:100] Creating Layer conv5_3
# I0302 07:57:43.050654  7434 net.cpp:434] conv5_3 <- conv5_2
# I0302 07:57:43.050711  7434 net.cpp:408] conv5_3 -> conv5_3
# I0302 07:57:43.077332  7434 net.cpp:150] Setting up conv5_3
# I0302 07:57:43.077490  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.077562  7434 net.cpp:165] Memory required for data: 7028900384
# I0302 07:57:43.077626  7434 layer_factory.hpp:77] Creating layer relu5_3
# I0302 07:57:43.077698  7434 net.cpp:100] Creating Layer relu5_3
# I0302 07:57:43.077754  7434 net.cpp:434] relu5_3 <- conv5_3
# I0302 07:57:43.077809  7434 net.cpp:395] relu5_3 -> conv5_3 (in-place)
# I0302 07:57:43.077867  7434 net.cpp:150] Setting up relu5_3
# I0302 07:57:43.077919  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.077973  7434 net.cpp:165] Memory required for data: 7052558880
# I0302 07:57:43.078025  7434 layer_factory.hpp:77] Creating layer pool5
# I0302 07:57:43.078081  7434 net.cpp:100] Creating Layer pool5
# I0302 07:57:43.078133  7434 net.cpp:434] pool5 <- conv5_3
# I0302 07:57:43.078191  7434 net.cpp:408] pool5 -> pool5
# I0302 07:57:43.078296  7434 net.cpp:150] Setting up pool5
# I0302 07:57:43.078363  7434 net.cpp:157] Top shape: 32 512 19 19 (5914624)
# I0302 07:57:43.078462  7434 net.cpp:165] Memory required for data: 7076217376
# I0302 07:57:43.078548  7434 layer_factory.hpp:77] Creating layer fc6
# I0302 07:57:43.078609  7434 net.cpp:100] Creating Layer fc6
# I0302 07:57:43.078670  7434 net.cpp:434] fc6 <- pool5
# I0302 07:57:43.078727  7434 net.cpp:408] fc6 -> fc6
# I0302 07:57:43.140012  7434 net.cpp:150] Setting up fc6
# I0302 07:57:43.140161  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.140230  7434 net.cpp:165] Memory required for data: 7123534368
# I0302 07:57:43.140311  7434 layer_factory.hpp:77] Creating layer relu6
# I0302 07:57:43.140380  7434 net.cpp:100] Creating Layer relu6
# I0302 07:57:43.141077  7434 net.cpp:434] relu6 <- fc6
# I0302 07:57:43.141181  7434 net.cpp:395] relu6 -> fc6 (in-place)
# I0302 07:57:43.141269  7434 net.cpp:150] Setting up relu6
# I0302 07:57:43.141328  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.141396  7434 net.cpp:165] Memory required for data: 7170851360
# I0302 07:57:43.141456  7434 layer_factory.hpp:77] Creating layer fc7
# I0302 07:57:43.141522  7434 net.cpp:100] Creating Layer fc7
# I0302 07:57:43.141577  7434 net.cpp:434] fc7 <- fc6
# I0302 07:57:43.141634  7434 net.cpp:408] fc7 -> fc7
# I0302 07:57:43.154436  7434 net.cpp:150] Setting up fc7
# I0302 07:57:43.154556  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.154625  7434 net.cpp:165] Memory required for data: 7218168352
# I0302 07:57:43.154703  7434 layer_factory.hpp:77] Creating layer relu7
# I0302 07:57:43.154767  7434 net.cpp:100] Creating Layer relu7
# I0302 07:57:43.154824  7434 net.cpp:434] relu7 <- fc7
# I0302 07:57:43.154882  7434 net.cpp:395] relu7 -> fc7 (in-place)
# I0302 07:57:43.154940  7434 net.cpp:150] Setting up relu7
# I0302 07:57:43.154994  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.155050  7434 net.cpp:165] Memory required for data: 7265485344
# I0302 07:57:43.155104  7434 layer_factory.hpp:77] Creating layer fc7_relu7_0_split
# I0302 07:57:43.155161  7434 net.cpp:100] Creating Layer fc7_relu7_0_split
# I0302 07:57:43.155215  7434 net.cpp:434] fc7_relu7_0_split <- fc7
# I0302 07:57:43.155269  7434 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_0
# I0302 07:57:43.155326  7434 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_1
# I0302 07:57:43.155385  7434 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_2
# I0302 07:57:43.155460  7434 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_3
# I0302 07:57:43.155575  7434 net.cpp:150] Setting up fc7_relu7_0_split
# I0302 07:57:43.155651  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.155712  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.155768  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.155822  7434 net.cpp:157] Top shape: 32 1024 19 19 (11829248)
# I0302 07:57:43.155877  7434 net.cpp:165] Memory required for data: 7454753312
# I0302 07:57:43.155930  7434 layer_factory.hpp:77] Creating layer conv6_1
# I0302 07:57:43.155989  7434 net.cpp:100] Creating Layer conv6_1
# I0302 07:57:43.156042  7434 net.cpp:434] conv6_1 <- fc7_relu7_0_split_0
# I0302 07:57:43.156100  7434 net.cpp:408] conv6_1 -> conv6_1
# I0302 07:57:43.160017  7434 net.cpp:150] Setting up conv6_1
# I0302 07:57:43.160135  7434 net.cpp:157] Top shape: 32 256 19 19 (2957312)
# I0302 07:57:43.160202  7434 net.cpp:165] Memory required for data: 7466582560
# I0302 07:57:43.160260  7434 layer_factory.hpp:77] Creating layer conv6_1_relu
# I0302 07:57:43.160317  7434 net.cpp:100] Creating Layer conv6_1_relu
# I0302 07:57:43.160372  7434 net.cpp:434] conv6_1_relu <- conv6_1
# I0302 07:57:43.160439  7434 net.cpp:395] conv6_1_relu -> conv6_1 (in-place)
# I0302 07:57:43.160501  7434 net.cpp:150] Setting up conv6_1_relu
# I0302 07:57:43.160562  7434 net.cpp:157] Top shape: 32 256 19 19 (2957312)
# I0302 07:57:43.160619  7434 net.cpp:165] Memory required for data: 7478411808
# I0302 07:57:43.160682  7434 layer_factory.hpp:77] Creating layer conv6_2
# I0302 07:57:43.160743  7434 net.cpp:100] Creating Layer conv6_2
# I0302 07:57:43.160796  7434 net.cpp:434] conv6_2 <- conv6_1
# I0302 07:57:43.160879  7434 net.cpp:408] conv6_2 -> conv6_2
# I0302 07:57:43.174381  7434 net.cpp:150] Setting up conv6_2
# I0302 07:57:43.174504  7434 net.cpp:157] Top shape: 32 512 10 10 (1638400)
# I0302 07:57:43.174567  7434 net.cpp:165] Memory required for data: 7484965408
# I0302 07:57:43.174628  7434 layer_factory.hpp:77] Creating layer conv6_2_relu
# I0302 07:57:43.174695  7434 net.cpp:100] Creating Layer conv6_2_relu
# I0302 07:57:43.174753  7434 net.cpp:434] conv6_2_relu <- conv6_2
# I0302 07:57:43.174811  7434 net.cpp:395] conv6_2_relu -> conv6_2 (in-place)
# I0302 07:57:43.174872  7434 net.cpp:150] Setting up conv6_2_relu
# I0302 07:57:43.174930  7434 net.cpp:157] Top shape: 32 512 10 10 (1638400)
# I0302 07:57:43.174986  7434 net.cpp:165] Memory required for data: 7491519008
# I0302 07:57:43.175041  7434 layer_factory.hpp:77] Creating layer conv6_2_conv6_2_relu_0_split
# I0302 07:57:43.175097  7434 net.cpp:100] Creating Layer conv6_2_conv6_2_relu_0_split
# I0302 07:57:43.175154  7434 net.cpp:434] conv6_2_conv6_2_relu_0_split <- conv6_2
# I0302 07:57:43.175212  7434 net.cpp:408] conv6_2_conv6_2_relu_0_split -> conv6_2_conv6_2_relu_0_split_0
# I0302 07:57:43.175269  7434 net.cpp:408] conv6_2_conv6_2_relu_0_split -> conv6_2_conv6_2_relu_0_split_1
# I0302 07:57:43.175326  7434 net.cpp:408] conv6_2_conv6_2_relu_0_split -> conv6_2_conv6_2_relu_0_split_2
# I0302 07:57:43.175381  7434 net.cpp:408] conv6_2_conv6_2_relu_0_split -> conv6_2_conv6_2_relu_0_split_3
# I0302 07:57:43.175515  7434 net.cpp:150] Setting up conv6_2_conv6_2_relu_0_split
# I0302 07:57:43.175585  7434 net.cpp:157] Top shape: 32 512 10 10 (1638400)
# I0302 07:57:43.175655  7434 net.cpp:157] Top shape: 32 512 10 10 (1638400)
# I0302 07:57:43.175719  7434 net.cpp:157] Top shape: 32 512 10 10 (1638400)
# I0302 07:57:43.175778  7434 net.cpp:157] Top shape: 32 512 10 10 (1638400)
# I0302 07:57:43.175845  7434 net.cpp:165] Memory required for data: 7517733408
# I0302 07:57:43.175899  7434 layer_factory.hpp:77] Creating layer conv7_1
# I0302 07:57:43.175967  7434 net.cpp:100] Creating Layer conv7_1
# I0302 07:57:43.176023  7434 net.cpp:434] conv7_1 <- conv6_2_conv6_2_relu_0_split_0
# I0302 07:57:43.176079  7434 net.cpp:408] conv7_1 -> conv7_1
# I0302 07:57:43.176909  7434 net.cpp:150] Setting up conv7_1
# I0302 07:57:43.177004  7434 net.cpp:157] Top shape: 32 128 10 10 (409600)
# I0302 07:57:43.177064  7434 net.cpp:165] Memory required for data: 7519371808
# I0302 07:57:43.177121  7434 layer_factory.hpp:77] Creating layer conv7_1_relu
# I0302 07:57:43.177182  7434 net.cpp:100] Creating Layer conv7_1_relu
# I0302 07:57:43.177237  7434 net.cpp:434] conv7_1_relu <- conv7_1
# I0302 07:57:43.177292  7434 net.cpp:395] conv7_1_relu -> conv7_1 (in-place)
# I0302 07:57:43.177348  7434 net.cpp:150] Setting up conv7_1_relu
# I0302 07:57:43.177418  7434 net.cpp:157] Top shape: 32 128 10 10 (409600)
# I0302 07:57:43.177477  7434 net.cpp:165] Memory required for data: 7521010208
# I0302 07:57:43.177536  7434 layer_factory.hpp:77] Creating layer conv7_2
# I0302 07:57:43.177598  7434 net.cpp:100] Creating Layer conv7_2
# I0302 07:57:43.177661  7434 net.cpp:434] conv7_2 <- conv7_1
# I0302 07:57:43.177718  7434 net.cpp:408] conv7_2 -> conv7_2
# I0302 07:57:43.182005  7434 net.cpp:150] Setting up conv7_2
# I0302 07:57:43.182116  7434 net.cpp:157] Top shape: 32 256 5 5 (204800)
# I0302 07:57:43.182185  7434 net.cpp:165] Memory required for data: 7521829408
# I0302 07:57:43.182245  7434 layer_factory.hpp:77] Creating layer conv7_2_relu
# I0302 07:57:43.182302  7434 net.cpp:100] Creating Layer conv7_2_relu
# I0302 07:57:43.182356  7434 net.cpp:434] conv7_2_relu <- conv7_2
# I0302 07:57:43.182422  7434 net.cpp:395] conv7_2_relu -> conv7_2 (in-place)
# I0302 07:57:43.182482  7434 net.cpp:150] Setting up conv7_2_relu
# I0302 07:57:43.182534  7434 net.cpp:157] Top shape: 32 256 5 5 (204800)
# I0302 07:57:43.182591  7434 net.cpp:165] Memory required for data: 7522648608
# I0302 07:57:43.182649  7434 layer_factory.hpp:77] Creating layer conv7_2_conv7_2_relu_0_split
# I0302 07:57:43.182708  7434 net.cpp:100] Creating Layer conv7_2_conv7_2_relu_0_split
# I0302 07:57:43.182763  7434 net.cpp:434] conv7_2_conv7_2_relu_0_split <- conv7_2
# I0302 07:57:43.182847  7434 net.cpp:408] conv7_2_conv7_2_relu_0_split -> conv7_2_conv7_2_relu_0_split_0
# I0302 07:57:43.182936  7434 net.cpp:408] conv7_2_conv7_2_relu_0_split -> conv7_2_conv7_2_relu_0_split_1
# I0302 07:57:43.182997  7434 net.cpp:408] conv7_2_conv7_2_relu_0_split -> conv7_2_conv7_2_relu_0_split_2
# I0302 07:57:43.183055  7434 net.cpp:408] conv7_2_conv7_2_relu_0_split -> conv7_2_conv7_2_relu_0_split_3
# ...
# I0302 07:57:43.899704  7434 net.cpp:228] pool6_mbox_loc does not need backward computation.
# I0302 07:57:43.899709  7434 net.cpp:228] conv8_2_mbox_priorbox does not need backward computation.
# I0302 07:57:43.899714  7434 net.cpp:228] conv8_2_mbox_conf_flat does not need backward computation.
# I0302 07:57:43.899718  7434 net.cpp:228] conv8_2_mbox_conf_perm does not need backward computation.
# I0302 07:57:43.899722  7434 net.cpp:228] conv8_2_mbox_conf does not need backward computation.
# I0302 07:57:43.899726  7434 net.cpp:228] conv8_2_mbox_loc_flat does not need backward computation.
# I0302 07:57:43.899731  7434 net.cpp:228] conv8_2_mbox_loc_perm does not need backward computation.
# I0302 07:57:43.899734  7434 net.cpp:228] conv8_2_mbox_loc does not need backward computation.
# I0302 07:57:43.899739  7434 net.cpp:228] conv7_2_mbox_priorbox does not need backward computation.
# I0302 07:57:43.899744  7434 net.cpp:228] conv7_2_mbox_conf_flat does not need backward computation.
# I0302 07:57:43.899749  7434 net.cpp:228] conv7_2_mbox_conf_perm does not need backward computation.
# I0302 07:57:43.899752  7434 net.cpp:228] conv7_2_mbox_conf does not need backward computation.
# I0302 07:57:43.899756  7434 net.cpp:228] conv7_2_mbox_loc_flat does not need backward computation.
# I0302 07:57:43.899760  7434 net.cpp:228] conv7_2_mbox_loc_perm does not need backward computation.
# I0302 07:57:43.899765  7434 net.cpp:228] conv7_2_mbox_loc does not need backward computation.
# I0302 07:57:43.899770  7434 net.cpp:228] conv6_2_mbox_priorbox does not need backward computation.
# I0302 07:57:43.899775  7434 net.cpp:228] conv6_2_mbox_conf_flat does not need backward computation.
# I0302 07:57:43.899778  7434 net.cpp:228] conv6_2_mbox_conf_perm does not need backward computation.
# I0302 07:57:43.899782  7434 net.cpp:228] conv6_2_mbox_conf does not need backward computation.
# I0302 07:57:43.899786  7434 net.cpp:228] conv6_2_mbox_loc_flat does not need backward computation.
# I0302 07:57:43.899791  7434 net.cpp:228] conv6_2_mbox_loc_perm does not need backward computation.
# I0302 07:57:43.899796  7434 net.cpp:228] conv6_2_mbox_loc does not need backward computation.
# I0302 07:57:43.899801  7434 net.cpp:228] fc7_mbox_priorbox does not need backward computation.
# I0302 07:57:43.899806  7434 net.cpp:228] fc7_mbox_conf_flat does not need backward computation.
# I0302 07:57:43.899809  7434 net.cpp:228] fc7_mbox_conf_perm does not need backward computation.
# I0302 07:57:43.899814  7434 net.cpp:228] fc7_mbox_conf does not need backward computation.
# I0302 07:57:43.899818  7434 net.cpp:228] fc7_mbox_loc_flat does not need backward computation.
# I0302 07:57:43.899822  7434 net.cpp:228] fc7_mbox_loc_perm does not need backward computation.
# I0302 07:57:43.899827  7434 net.cpp:228] fc7_mbox_loc does not need backward computation.
# I0302 07:57:43.899832  7434 net.cpp:228] conv4_3_norm_mbox_priorbox does not need backward computation.
# I0302 07:57:43.899837  7434 net.cpp:228] conv4_3_norm_mbox_conf_flat does not need backward computation.
# I0302 07:57:43.899840  7434 net.cpp:228] conv4_3_norm_mbox_conf_perm does not need backward computation.
# I0302 07:57:43.899845  7434 net.cpp:228] conv4_3_norm_mbox_conf does not need backward computation.
# I0302 07:57:43.899849  7434 net.cpp:228] conv4_3_norm_mbox_loc_flat does not need backward computation.
# I0302 07:57:43.899863  7434 net.cpp:228] conv4_3_norm_mbox_loc_perm does not need backward computation.
# I0302 07:57:43.899868  7434 net.cpp:228] conv4_3_norm_mbox_loc does not need backward computation.
# I0302 07:57:43.899873  7434 net.cpp:228] conv4_3_norm_conv4_3_norm_0_split does not need backward computation.
# I0302 07:57:43.899876  7434 net.cpp:228] conv4_3_norm does not need backward computation.
# I0302 07:57:43.899881  7434 net.cpp:228] pool6_pool6_0_split does not need backward computation.
# I0302 07:57:43.899886  7434 net.cpp:228] pool6 does not need backward computation.
# I0302 07:57:43.899890  7434 net.cpp:228] conv8_2_conv8_2_relu_0_split does not need backward computation.
# I0302 07:57:43.899894  7434 net.cpp:228] conv8_2_relu does not need backward computation.
# I0302 07:57:43.899899  7434 net.cpp:228] conv8_2 does not need backward computation.
# I0302 07:57:43.899904  7434 net.cpp:228] conv8_1_relu does not need backward computation.
# I0302 07:57:43.899907  7434 net.cpp:228] conv8_1 does not need backward computation.
# I0302 07:57:43.899912  7434 net.cpp:228] conv7_2_conv7_2_relu_0_split does not need backward computation.
# I0302 07:57:43.899916  7434 net.cpp:228] conv7_2_relu does not need backward computation.
# I0302 07:57:43.899920  7434 net.cpp:228] conv7_2 does not need backward computation.
# I0302 07:57:43.899924  7434 net.cpp:228] conv7_1_relu does not need backward computation.
# I0302 07:57:43.899930  7434 net.cpp:228] conv7_1 does not need backward computation.
# I0302 07:57:43.899935  7434 net.cpp:228] conv6_2_conv6_2_relu_0_split does not need backward computation.
# I0302 07:57:43.899938  7434 net.cpp:228] conv6_2_relu does not need backward computation.
# I0302 07:57:43.899942  7434 net.cpp:228] conv6_2 does not need backward computation.
# I0302 07:57:43.899946  7434 net.cpp:228] conv6_1_relu does not need backward computation.
# I0302 07:57:43.899950  7434 net.cpp:228] conv6_1 does not need backward computation.
# I0302 07:57:43.899955  7434 net.cpp:228] fc7_relu7_0_split does not need backward computation.
# I0302 07:57:43.899960  7434 net.cpp:228] relu7 does not need backward computation.
# I0302 07:57:43.899963  7434 net.cpp:228] fc7 does not need backward computation.
# I0302 07:57:43.899967  7434 net.cpp:228] relu6 does not need backward computation.
# I0302 07:57:43.899971  7434 net.cpp:228] fc6 does not need backward computation.
# I0302 07:57:43.899976  7434 net.cpp:228] pool5 does not need backward computation.
# I0302 07:57:43.899979  7434 net.cpp:228] relu5_3 does not need backward computation.
# I0302 07:57:43.899983  7434 net.cpp:228] conv5_3 does not need backward computation.
# I0302 07:57:43.899987  7434 net.cpp:228] relu5_2 does not need backward computation.
# I0302 07:57:43.899991  7434 net.cpp:228] conv5_2 does not need backward computation.
# I0302 07:57:43.899996  7434 net.cpp:228] relu5_1 does not need backward computation.
# I0302 07:57:43.899999  7434 net.cpp:228] conv5_1 does not need backward computation.
# I0302 07:57:43.900003  7434 net.cpp:228] pool4 does not need backward computation.
# I0302 07:57:43.900008  7434 net.cpp:228] conv4_3_relu4_3_0_split does not need backward computation.
# I0302 07:57:43.900013  7434 net.cpp:228] relu4_3 does not need backward computation.
# I0302 07:57:43.900017  7434 net.cpp:228] conv4_3 does not need backward computation.
# I0302 07:57:43.900022  7434 net.cpp:228] relu4_2 does not need backward computation.
# I0302 07:57:43.900025  7434 net.cpp:228] conv4_2 does not need backward computation.
# I0302 07:57:43.900029  7434 net.cpp:228] relu4_1 does not need backward computation.
# I0302 07:57:43.900033  7434 net.cpp:228] conv4_1 does not need backward computation.
# I0302 07:57:43.900038  7434 net.cpp:228] pool3 does not need backward computation.
# I0302 07:57:43.900043  7434 net.cpp:228] relu3_3 does not need backward computation.
# I0302 07:57:43.900046  7434 net.cpp:228] conv3_3 does not need backward computation.
# I0302 07:57:43.900050  7434 net.cpp:228] relu3_2 does not need backward computation.
# I0302 07:57:43.900053  7434 net.cpp:228] conv3_2 does not need backward computation.
# I0302 07:57:43.900065  7434 net.cpp:228] relu3_1 does not need backward computation.
# I0302 07:57:43.900069  7434 net.cpp:228] conv3_1 does not need backward computation.
# I0302 07:57:43.900074  7434 net.cpp:228] pool2 does not need backward computation.
# I0302 07:57:43.900077  7434 net.cpp:228] relu2_2 does not need backward computation.
# I0302 07:57:43.900081  7434 net.cpp:228] conv2_2 does not need backward computation.
# I0302 07:57:43.900084  7434 net.cpp:228] relu2_1 does not need backward computation.
# I0302 07:57:43.900089  7434 net.cpp:228] conv2_1 does not need backward computation.
# I0302 07:57:43.900094  7434 net.cpp:228] pool1 does not need backward computation.
# I0302 07:57:43.900097  7434 net.cpp:228] relu1_2 does not need backward computation.
# I0302 07:57:43.900101  7434 net.cpp:228] conv1_2 does not need backward computation.
# I0302 07:57:43.900104  7434 net.cpp:228] relu1_1 does not need backward computation.
# I0302 07:57:43.900108  7434 net.cpp:228] conv1_1 does not need backward computation.
# I0302 07:57:43.900113  7434 net.cpp:228] data_data_0_split does not need backward computation.
# I0302 07:57:43.900118  7434 net.cpp:228] data does not need backward computation.
# I0302 07:57:43.900122  7434 net.cpp:270] This network produces output detection_eval
# I0302 07:57:43.900207  7434 net.cpp:283] Network initialization done.
# I0302 07:57:43.900604  7434 solver.cpp:63] Solver scaffolding done.
# I0302 07:57:43.902069  7434 caffe.cpp:155] Finetuning from examples/TextBoxes/TextBoxes_icdar13.caffemodel
# I0302 07:57:44.516891  7434 net.cpp:761] Ignoring source layer mbox_loss
# I0302 07:57:44.522452  7434 caffe.cpp:251] Starting Optimization
# I0302 07:57:44.522615  7434 solver.cpp:282] Solving VGG_text_longer_conv_300x300_train
# I0302 07:57:44.522701  7434 solver.cpp:283] Learning Rate Policy: step
# I0302 07:57:44.526737  7434 blocking_queue.cpp:50] Data layer prefetch queue empty
# I0302 07:57:52.063944  7434 solver.cpp:231] Iteration 0, loss = 6.79235
# I0302 07:57:52.063992  7434 solver.cpp:247]     Train net output #0: mbox_loss = 6.79235 (* 1 = 6.79235 loss)
# I0302 07:57:52.064016  7434 sgd_solver.cpp:106] Iteration 0, lr = 0.0001
# I0302 07:58:46.391119  7434 solver.cpp:231] Iteration 10, loss = 5.71123
# I0302 07:58:46.391235  7434 solver.cpp:247]     Train net output #0: mbox_loss = 4.88062 (* 1 = 4.88062 loss)
# I0302 07:58:46.391247  7434 sgd_solver.cpp:106] Iteration 10, lr = 0.0001
# I0302 07:59:37.778326  7434 solver.cpp:231] Iteration 20, loss = 4.3804
# I0302 07:59:37.778399  7434 solver.cpp:247]     Train net output #0: mbox_loss = 4.1506 (* 1 = 4.1506 loss)
# I0302 07:59:37.778412  7434 sgd_solver.cpp:106] Iteration 20, lr = 0.0001
# I0302 08:00:25.184056  7434 solver.cpp:231] Iteration 30, loss = 3.97484
# I0302 08:00:25.184142  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.76819 (* 1 = 3.76819 loss)
# I0302 08:00:25.184154  7434 sgd_solver.cpp:106] Iteration 30, lr = 0.0001
# I0302 08:01:17.016647  7434 solver.cpp:231] Iteration 40, loss = 3.65161
# I0302 08:01:17.016726  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.50426 (* 1 = 3.50426 loss)
# I0302 08:01:17.016744  7434 sgd_solver.cpp:106] Iteration 40, lr = 0.0001
# I0302 08:02:04.598261  7434 solver.cpp:421] Iteration 50, Testing net (#0)
# I0302 08:02:05.107879  7434 net.cpp:693] Ignoring source layer mbox_loss
# I0302 08:02:42.625622  7434 solver.cpp:531]     Test net output #0: detection_eval = 0.663847
# I0302 08:02:48.081266  7434 solver.cpp:231] Iteration 50, loss = 3.44514
# I0302 08:02:48.081310  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.09562 (* 1 = 3.09562 loss)
# I0302 08:02:48.081321  7434 sgd_solver.cpp:106] Iteration 50, lr = 0.0001
# I0302 08:03:40.476738  7434 solver.cpp:231] Iteration 60, loss = 3.28208
# I0302 08:03:40.476822  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.29873 (* 1 = 3.29873 loss)
# I0302 08:03:40.476836  7434 sgd_solver.cpp:106] Iteration 60, lr = 0.0001
# I0302 08:04:27.460466  7434 solver.cpp:231] Iteration 70, loss = 3.20486
# I0302 08:04:27.460578  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.16498 (* 1 = 3.16498 loss)
# I0302 08:04:27.460589  7434 sgd_solver.cpp:106] Iteration 70, lr = 0.0001
# I0302 08:05:21.558960  7434 solver.cpp:231] Iteration 80, loss = 3.07413
# I0302 08:05:21.559034  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.06142 (* 1 = 3.06142 loss)
# I0302 08:05:21.559046  7434 sgd_solver.cpp:106] Iteration 80, lr = 0.0001
# I0302 08:06:15.397652  7434 solver.cpp:231] Iteration 90, loss = 3.0086
# I0302 08:06:15.397727  7434 solver.cpp:247]     Train net output #0: mbox_loss = 3.03381 (* 1 = 3.03381 loss)
# I0302 08:06:15.397740  7434 sgd_solver.cpp:106] Iteration 90, lr = 0.0001
# I0302 08:07:02.793443  7434 solver.cpp:421] Iteration 100, Testing net (#0)
# I0302 08:07:02.793596  7434 net.cpp:693] Ignoring source layer mbox_loss
# I0302 08:07:39.613478  7434 solver.cpp:531]     Test net output #0: detection_eval = 0.678762
# I0302 08:07:45.101495  7434 solver.cpp:231] Iteration 100, loss = 2.9864
# I0302 08:07:45.101541  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.74547 (* 1 = 2.74547 loss)
# I0302 08:07:45.101552  7434 sgd_solver.cpp:106] Iteration 100, lr = 0.0001
# I0302 08:08:36.017464  7434 solver.cpp:231] Iteration 110, loss = 2.83675
# I0302 08:08:36.017593  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.7255 (* 1 = 2.7255 loss)
# I0302 08:08:36.017604  7434 sgd_solver.cpp:106] Iteration 110, lr = 0.0001
# I0302 08:09:31.715478  7434 solver.cpp:231] Iteration 120, loss = 2.76662
# I0302 08:09:31.715553  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.62243 (* 1 = 2.62243 loss)
# I0302 08:09:31.715565  7434 sgd_solver.cpp:106] Iteration 120, lr = 0.0001
# I0302 08:10:29.220633  7434 solver.cpp:231] Iteration 130, loss = 2.69832
# I0302 08:10:29.220772  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.91306 (* 1 = 2.91306 loss)
# I0302 08:10:29.220785  7434 sgd_solver.cpp:106] Iteration 130, lr = 0.0001
# I0302 08:11:25.547148  7434 solver.cpp:231] Iteration 140, loss = 2.66214
# I0302 08:11:25.547255  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.91715 (* 1 = 2.91715 loss)
# I0302 08:11:25.547267  7434 sgd_solver.cpp:106] Iteration 140, lr = 0.0001
# I0302 08:12:12.239133  7434 solver.cpp:421] Iteration 150, Testing net (#0)
# I0302 08:12:12.239262  7434 net.cpp:693] Ignoring source layer mbox_loss
# I0302 08:12:48.975983  7434 solver.cpp:531]     Test net output #0: detection_eval = 0.690632
# I0302 08:12:55.584723  7434 solver.cpp:231] Iteration 150, loss = 2.67734
# I0302 08:12:55.584981  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.9707 (* 1 = 2.9707 loss)
# I0302 08:12:55.585081  7434 sgd_solver.cpp:106] Iteration 150, lr = 0.0001
# I0302 08:13:44.666678  7434 solver.cpp:231] Iteration 160, loss = 2.63837
# I0302 08:13:44.666980  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.43825 (* 1 = 2.43825 loss)
# I0302 08:13:44.667081  7434 sgd_solver.cpp:106] Iteration 160, lr = 0.0001
# I0302 08:14:39.481719  7434 solver.cpp:231] Iteration 170, loss = 2.59759
# I0302 08:14:39.481845  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.50589 (* 1 = 2.50589 loss)
# I0302 08:14:39.481858  7434 sgd_solver.cpp:106] Iteration 170, lr = 0.0001
# I0302 08:15:29.206745  7434 solver.cpp:231] Iteration 180, loss = 2.60461
# I0302 08:15:29.207037  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.56571 (* 1 = 2.56571 loss)
# I0302 08:15:29.207119  7434 sgd_solver.cpp:106] Iteration 180, lr = 0.0001
# I0302 08:16:19.547482  7434 solver.cpp:231] Iteration 190, loss = 2.62641
# I0302 08:16:19.547606  7434 solver.cpp:247]     Train net output #0: mbox_loss = 2.57184 (* 1 = 2.57184 loss)
# I0302 08:16:19.547619  7434 sgd_solver.cpp:106] Iteration 190, lr = 0.0001
# I0302 08:17:03.967602  7434 solver.cpp:581] Snapshotting to binary proto file models/VGGNet/text/longer_conv_300x300/VGG_text_longer_conv_300x300_iter_200.caffemodel
# I0302 08:17:05.465308  7434 sgd_solver.cpp:273] Snapshotting solver state to binary proto file models/VGGNet/text/longer_conv_300x300/VGG_text_longer_conv_300x300_iter_200.solverstate
# I0302 08:17:11.261262  7434 solver.cpp:320] Iteration 200, loss = 2.48367
# I0302 08:17:11.262419  7434 solver.cpp:421] Iteration 200, Testing net (#0)
# I0302 08:17:11.262643  7434 net.cpp:693] Ignoring source layer mbox_loss
# I0302 08:17:48.356676  7434 solver.cpp:531]     Test net output #0: detection_eval = 0.692887
# I0302 08:17:48.363416  7434 solver.cpp:325] Optimization Done.
# I0302 08:17:48.363592  7434 caffe.cpp:254] Optimization Done.

# %% [markdown]
# **RUNNING DEMO AFTER TRAINING**

# %%
! python examples/TextBoxes/demo.py
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W0302 08:23:48.320776 13994 _caffe.cpp:122] DEPRECATION WARNING - deprecated use of Python interface
# W0302 08:23:48.320809 13994 _caffe.cpp:123] Use this instead (with the named "weights" parameter):
# W0302 08:23:48.320813 13994 _caffe.cpp:125] Net('./models/VGGNet/text/longer_conv_300x300/deploy.prototxt', 1, weights='./models/VGGNet/text/longer_conv_300x300/VGG_text_longer_conv_300x300_iter_200.caffemodel')
# I0302 08:23:48.326949 13994 upgrade_proto.cpp:66] Attempting to upgrade input file specified using deprecated input fields: ./models/VGGNet/text/longer_conv_300x300/deploy.prototxt
# I0302 08:23:48.327044 13994 upgrade_proto.cpp:69] Successfully upgraded file specified using deprecated input fields.
# W0302 08:23:48.327057 13994 upgrade_proto.cpp:71] Note that future Caffe releases will only support input layers and not input fields.
# I0302 08:23:48.327425 13994 net.cpp:58] Initializing net from parameters:
# name: "VGG_text_longer_conv_300x300_deploy"
# state {
#   phase: TEST
#   level: 0
# }
# layer {
#   name: "input"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 1
#       dim: 3
#       dim: 300
#       dim: 300
#     }
#   }
# }
# layer {
#   name: "conv1_1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1_1"
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1_1"
#   type: "ReLU"
#   bottom: "conv1_1"
#   top: "conv1_1"
# }
# layer {
#   name: "conv1_2"
#   type: "Convolution"
#   bottom: "conv1_1"
#   top: "conv1_2"
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1_2"
#   type: "ReLU"
#   bottom: "conv1_2"
#   top: "conv1_2"
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "conv1_2"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 2
#     stride: 2
#   }
# }
# layer {
#   name: "conv2_1"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2_1"
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu2_1"
#   type: "ReLU"
#   bottom: "conv2_1"
#   top: "conv2_1"
# }
# layer {
#   name: "conv2_2"
#   type: "Convolution"
#   bottom: "conv2_1"
#   top: "conv2_2"
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   param {
#     lr_mult: 0
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu2_2"
#   type: "ReLU"
#   bottom: "conv2_2"
#   top: "conv2_2"
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "conv2_2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 2
#     stride: 2
#   }
# }
# layer {
#   name: "conv3_1"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3_1"
#   type: "ReLU"
#   bottom: "conv3_1"
#   top: "conv3_1"
# }
# layer {
#   name: "conv3_2"
#   type: "Convolution"
#   bottom: "conv3_1"
#   top: "conv3_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3_2"
#   type: "ReLU"
#   bottom: "conv3_2"
#   top: "conv3_2"
# }
# layer {
#   name: "conv3_3"
#   type: "Convolution"
#   bottom: "conv3_2"
#   top: "conv3_3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3_3"
#   type: "ReLU"
#   bottom: "conv3_3"
#   top: "conv3_3"
# }
# layer {
#   name: "pool3"
#   type: "Pooling"
#   bottom: "conv3_3"
#   top: "pool3"
#   pooling_param {
#     pool: MAX
#     kernel_size: 2
#     stride: 2
#   }
# }
# layer {
#   name: "conv4_1"
#   type: "Convolution"
#   bottom: "pool3"
#   top: "conv4_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu4_1"
#   type: "ReLU"
#   bottom: "conv4_1"
#   top: "conv4_1"
# }
# layer {
#   name: "conv4_2"
#   type: "Convolution"
#   bottom: "conv4_1"
#   top: "conv4_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu4_2"
#   type: "ReLU"
#   bottom: "conv4_2"
#   top: "conv4_2"
# }
# layer {
#   name: "conv4_3"
#   type: "Convolution"
#   bottom: "conv4_2"
#   top: "conv4_3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu4_3"
#   type: "ReLU"
#   bottom: "conv4_3"
#   top: "conv4_3"
# }
# layer {
#   name: "pool4"
#   type: "Pooling"
#   bottom: "conv4_3"
#   top: "pool4"
#   pooling_param {
#     pool: MAX
#     kernel_size: 2
#     stride: 2
#   }
# }
# layer {
#   name: "conv5_1"
#   type: "Convolution"
#   bottom: "pool4"
#   top: "conv5_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu5_1"
#   type: "ReLU"
#   bottom: "conv5_1"
#   top: "conv5_1"
# }
# layer {
#   name: "conv5_2"
#   type: "Convolution"
#   bottom: "conv5_1"
#   top: "conv5_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu5_2"
#   type: "ReLU"
#   bottom: "conv5_2"
#   top: "conv5_2"
# }
# layer {
#   name: "conv5_3"
#   type: "Convolution"
#   bottom: "conv5_2"
#   top: "conv5_3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu5_3"
#   type: "ReLU"
#   bottom: "conv5_3"
#   top: "conv5_3"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5_3"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "fc6"
#   type: "Convolution"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 1024
#     pad: 6
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     dilation: 6
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "fc7"
#   type: "Convolution"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 1024
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "conv6_1"
#   type: "Convolution"
#   bottom: "fc7"
#   top: "conv6_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 0
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv6_1_relu"
#   type: "ReLU"
#   bottom: "conv6_1"
#   top: "conv6_1"
# }
# layer {
#   name: "conv6_2"
#   type: "Convolution"
#   bottom: "conv6_1"
#   top: "conv6_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 2
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv6_2_relu"
#   type: "ReLU"
#   bottom: "conv6_2"
#   top: "conv6_2"
# }
# layer {
#   name: "conv7_1"
#   type: "Convolution"
#   bottom: "conv6_2"
#   top: "conv7_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 0
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv7_1_relu"
#   type: "ReLU"
#   bottom: "conv7_1"
#   top: "conv7_1"
# }
# layer {
#   name: "conv7_2"
#   type: "Convolution"
#   bottom: "conv7_1"
#   top: "conv7_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 2
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv7_2_relu"
#   type: "ReLU"
#   bottom: "conv7_2"
#   top: "conv7_2"
# }
# layer {
#   name: "conv8_1"
#   type: "Convolution"
#   bottom: "conv7_2"
#   top: "conv8_1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 0
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv8_1_relu"
#   type: "ReLU"
#   bottom: "conv8_1"
#   top: "conv8_1"
# }
# layer {
#   name: "conv8_2"
#   type: "Convolution"
#   bottom: "conv8_1"
#   top: "conv8_2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 2
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "conv8_2_relu"
#   type: "ReLU"
#   bottom: "conv8_2"
#   top: "conv8_2"
# }
# layer {
#   name: "pool6"
#   type: "Pooling"
#   bottom: "conv8_2"
#   top: "pool6"
#   pooling_param {
#     pool: AVE
#     global_pooling: true
#   }
# }
# layer {
#   name: "conv4_3_norm"
#   type: "Normalize"
#   bottom: "conv4_3"
#   top: "conv4_3_norm"
#   norm_param {
#     across_spatial: false
#     scale_filler {
#       type: "constant"
#       value: 20
#     }
#     channel_shared: false
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_loc"
#   type: "Convolution"
#   bottom: "conv4_3_norm"
#   top: "conv4_3_norm_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 48
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv4_3_norm_mbox_loc"
#   top: "conv4_3_norm_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv4_3_norm_mbox_loc_perm"
#   top: "conv4_3_norm_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_conf"
#   type: "Convolution"
#   bottom: "conv4_3_norm"
#   top: "conv4_3_norm_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 24
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv4_3_norm_mbox_conf"
#   top: "conv4_3_norm_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv4_3_norm_mbox_conf_perm"
#   top: "conv4_3_norm_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv4_3_norm_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv4_3_norm"
#   bottom: "data"
#   top: "conv4_3_norm_mbox_priorbox"
#   prior_box_param {
#     min_size: 30
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "fc7_mbox_loc"
#   type: "Convolution"
#   bottom: "fc7"
#   top: "fc7_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "fc7_mbox_loc_perm"
#   type: "Permute"
#   bottom: "fc7_mbox_loc"
#   top: "fc7_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "fc7_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "fc7_mbox_loc_perm"
#   top: "fc7_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "fc7_mbox_conf"
#   type: "Convolution"
#   bottom: "fc7"
#   top: "fc7_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "fc7_mbox_conf_perm"
#   type: "Permute"
#   bottom: "fc7_mbox_conf"
#   top: "fc7_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "fc7_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "fc7_mbox_conf_perm"
#   top: "fc7_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "fc7_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "fc7"
#   bottom: "data"
#   top: "fc7_mbox_priorbox"
#   prior_box_param {
#     min_size: 60
#     max_size: 114
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "conv6_2_mbox_loc"
#   type: "Convolution"
#   bottom: "conv6_2"
#   top: "conv6_2_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv6_2_mbox_loc"
#   top: "conv6_2_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv6_2_mbox_loc_perm"
#   top: "conv6_2_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_conf"
#   type: "Convolution"
#   bottom: "conv6_2"
#   top: "conv6_2_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv6_2_mbox_conf"
#   top: "conv6_2_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv6_2_mbox_conf_perm"
#   top: "conv6_2_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv6_2_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv6_2"
#   bottom: "data"
#   top: "conv6_2_mbox_priorbox"
#   prior_box_param {
#     min_size: 114
#     max_size: 168
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "conv7_2_mbox_loc"
#   type: "Convolution"
#   bottom: "conv7_2"
#   top: "conv7_2_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv7_2_mbox_loc"
#   top: "conv7_2_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv7_2_mbox_loc_perm"
#   top: "conv7_2_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_conf"
#   type: "Convolution"
#   bottom: "conv7_2"
#   top: "conv7_2_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv7_2_mbox_conf"
#   top: "conv7_2_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv7_2_mbox_conf_perm"
#   top: "conv7_2_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv7_2_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv7_2"
#   bottom: "data"
#   top: "conv7_2_mbox_priorbox"
#   prior_box_param {
#     min_size: 168
#     max_size: 222
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "conv8_2_mbox_loc"
#   type: "Convolution"
#   bottom: "conv8_2"
#   top: "conv8_2_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_loc_perm"
#   type: "Permute"
#   bottom: "conv8_2_mbox_loc"
#   top: "conv8_2_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "conv8_2_mbox_loc_perm"
#   top: "conv8_2_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_conf"
#   type: "Convolution"
#   bottom: "conv8_2"
#   top: "conv8_2_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_conf_perm"
#   type: "Permute"
#   bottom: "conv8_2_mbox_conf"
#   top: "conv8_2_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "conv8_2_mbox_conf_perm"
#   top: "conv8_2_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "conv8_2_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "conv8_2"
#   bottom: "data"
#   top: "conv8_2_mbox_priorbox"
#   prior_box_param {
#     min_size: 222
#     max_size: 276
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "pool6_mbox_loc"
#   type: "Convolution"
#   bottom: "pool6"
#   top: "pool6_mbox_loc"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 56
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "pool6_mbox_loc_perm"
#   type: "Permute"
#   bottom: "pool6_mbox_loc"
#   top: "pool6_mbox_loc_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "pool6_mbox_loc_flat"
#   type: "Flatten"
#   bottom: "pool6_mbox_loc_perm"
#   top: "pool6_mbox_loc_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "pool6_mbox_conf"
#   type: "Convolution"
#   bottom: "pool6"
#   top: "pool6_mbox_conf"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 28
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#     pad_h: 0
#     pad_w: 2
#     kernel_h: 1
#     kernel_w: 5
#     stride_h: 1
#     stride_w: 1
#   }
# }
# layer {
#   name: "pool6_mbox_conf_perm"
#   type: "Permute"
#   bottom: "pool6_mbox_conf"
#   top: "pool6_mbox_conf_perm"
#   permute_param {
#     order: 0
#     order: 2
#     order: 3
#     order: 1
#   }
# }
# layer {
#   name: "pool6_mbox_conf_flat"
#   type: "Flatten"
#   bottom: "pool6_mbox_conf_perm"
#   top: "pool6_mbox_conf_flat"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "pool6_mbox_priorbox"
#   type: "PriorBox"
#   bottom: "pool6"
#   bottom: "data"
#   top: "pool6_mbox_priorbox"
#   prior_box_param {
#     min_size: 276
#     max_size: 330
#     aspect_ratio: 2
#     aspect_ratio: 3
#     aspect_ratio: 5
#     aspect_ratio: 7
#     aspect_ratio: 10
#     flip: false
#     clip: true
#     variance: 0.1
#     variance: 0.1
#     variance: 0.2
#     variance: 0.2
#   }
# }
# layer {
#   name: "mbox_loc"
#   type: "Concat"
#   bottom: "conv4_3_norm_mbox_loc_flat"
#   bottom: "fc7_mbox_loc_flat"
#   bottom: "conv6_2_mbox_loc_flat"
#   bottom: "conv7_2_mbox_loc_flat"
#   bottom: "conv8_2_mbox_loc_flat"
#   bottom: "pool6_mbox_loc_flat"
#   top: "mbox_loc"
#   concat_param {
#     axis: 1
#   }
# }
# layer {
#   name: "mbox_conf"
#   type: "Concat"
#   bottom: "conv4_3_norm_mbox_conf_flat"
#   bottom: "fc7_mbox_conf_flat"
#   bottom: "conv6_2_mbox_conf_flat"
#   bottom: "conv7_2_mbox_conf_flat"
#   bottom: "conv8_2_mbox_conf_flat"
#   bottom: "pool6_mbox_conf_flat"
#   top: "mbox_conf"
#   concat_param {
#     axis: 1
#   }
# }
# layer {
#   name: "mbox_priorbox"
#   type: "Concat"
#   bottom: "conv4_3_norm_mbox_priorbox"
#   bottom: "fc7_mbox_priorbox"
#   bottom: "conv6_2_mbox_priorbox"
#   bottom: "conv7_2_mbox_priorbox"
#   bottom: "conv8_2_mbox_priorbox"
#   bottom: "pool6_mbox_priorbox"
#   top: "mbox_priorbox"
#   concat_param {
#     axis: 2
#   }
# }
# layer {
#   name: "mbox_conf_reshape"
#   type: "Reshape"
#   bottom: "mbox_conf"
#   top: "mbox_conf_reshape"
#   reshape_param {
#     shape {
#       dim: 0
#       dim: -1
#       dim: 2
#     }
#   }
# }
# layer {
#   name: "mbox_conf_softmax"
#   type: "Softmax"
#   bottom: "mbox_conf_reshape"
#   top: "mbox_conf_softmax"
#   softmax_param {
#     axis: 2
#   }
# }
# layer {
#   name: "mbox_conf_flatten"
#   type: "Flatten"
#   bottom: "mbox_conf_softmax"
#   top: "mbox_conf_flatten"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "detection_out"
#   type: "DetectionOutput"
#   bottom: "mbox_loc"
#   bottom: "mbox_conf_flatten"
#   bottom: "mbox_priorbox"
#   top: "detection_out"
#   include {
#     phase: TEST
#   }
#   detection_output_param {
#     num_classes: 2
#     share_location: true
#     background_label_id: 0
#     nms_param {
#       nms_threshold: 0.45
#       top_k: 400
#     }
#     save_output_param {
#       output_directory: "/root/data/text/results/text/longer_conv_300x300/Main"
#       output_name_prefix: "comp4_det_test_"
#       output_format: "VOC"
#       label_map_file: "examples/TextBoxes/labelmap_voc.prototxt"
#       num_test_image: 233
#     }
#     code_type: CENTER_SIZE
#     keep_top_k: 200
#     confidence_threshold: 0.01
#   }
# }
# I0302 08:23:48.390295 13994 layer_factory.hpp:77] Creating layer input
# I0302 08:23:48.390542 13994 net.cpp:100] Creating Layer input
# I0302 08:23:48.390559 13994 net.cpp:408] input -> data
# I0302 08:23:48.409085 13994 net.cpp:150] Setting up input
# I0302 08:23:48.409106 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409114 13994 net.cpp:165] Memory required for data: 1080000
# I0302 08:23:48.409121 13994 layer_factory.hpp:77] Creating layer data_input_0_split
# I0302 08:23:48.409332 13994 net.cpp:100] Creating Layer data_input_0_split
# I0302 08:23:48.409348 13994 net.cpp:434] data_input_0_split <- data
# I0302 08:23:48.409363 13994 net.cpp:408] data_input_0_split -> data_input_0_split_0
# I0302 08:23:48.409379 13994 net.cpp:408] data_input_0_split -> data_input_0_split_1
# I0302 08:23:48.409400 13994 net.cpp:408] data_input_0_split -> data_input_0_split_2
# I0302 08:23:48.409410 13994 net.cpp:408] data_input_0_split -> data_input_0_split_3
# I0302 08:23:48.409421 13994 net.cpp:408] data_input_0_split -> data_input_0_split_4
# I0302 08:23:48.409430 13994 net.cpp:408] data_input_0_split -> data_input_0_split_5
# I0302 08:23:48.409440 13994 net.cpp:408] data_input_0_split -> data_input_0_split_6
# I0302 08:23:48.409682 13994 net.cpp:150] Setting up data_input_0_split
# I0302 08:23:48.409696 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409704 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409710 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409718 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409725 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409734 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409741 13994 net.cpp:157] Top shape: 1 3 300 300 (270000)
# I0302 08:23:48.409749 13994 net.cpp:165] Memory required for data: 8640000
# I0302 08:23:48.409756 13994 layer_factory.hpp:77] Creating layer conv1_1
# I0302 08:23:48.409782 13994 net.cpp:100] Creating Layer conv1_1
# I0302 08:23:48.409790 13994 net.cpp:434] conv1_1 <- data_input_0_split_0
# I0302 08:23:48.409801 13994 net.cpp:408] conv1_1 -> conv1_1
# I0302 08:23:48.410565 13994 net.cpp:150] Setting up conv1_1
# I0302 08:23:48.410581 13994 net.cpp:157] Top shape: 1 64 300 300 (5760000)
# I0302 08:23:48.410588 13994 net.cpp:165] Memory required for data: 31680000
# I0302 08:23:48.410604 13994 layer_factory.hpp:77] Creating layer relu1_1
# I0302 08:23:48.410615 13994 net.cpp:100] Creating Layer relu1_1
# I0302 08:23:48.410622 13994 net.cpp:434] relu1_1 <- conv1_1
# I0302 08:23:48.410631 13994 net.cpp:395] relu1_1 -> conv1_1 (in-place)
# I0302 08:23:48.410794 13994 net.cpp:150] Setting up relu1_1
# I0302 08:23:48.410805 13994 net.cpp:157] Top shape: 1 64 300 300 (5760000)
# I0302 08:23:48.410813 13994 net.cpp:165] Memory required for data: 54720000
# I0302 08:23:48.410822 13994 layer_factory.hpp:77] Creating layer conv1_2
# I0302 08:23:48.410840 13994 net.cpp:100] Creating Layer conv1_2
# I0302 08:23:48.410846 13994 net.cpp:434] conv1_2 <- conv1_1
# I0302 08:23:48.410856 13994 net.cpp:408] conv1_2 -> conv1_2
# I0302 08:23:48.411221 13994 net.cpp:150] Setting up conv1_2
# I0302 08:23:48.411232 13994 net.cpp:157] Top shape: 1 64 300 300 (5760000)
# I0302 08:23:48.411238 13994 net.cpp:165] Memory required for data: 77760000
# I0302 08:23:48.411247 13994 layer_factory.hpp:77] Creating layer relu1_2
# I0302 08:23:48.411260 13994 net.cpp:100] Creating Layer relu1_2
# I0302 08:23:48.411264 13994 net.cpp:434] relu1_2 <- conv1_2
# I0302 08:23:48.411273 13994 net.cpp:395] relu1_2 -> conv1_2 (in-place)
# I0302 08:23:48.411283 13994 net.cpp:150] Setting up relu1_2
# I0302 08:23:48.411288 13994 net.cpp:157] Top shape: 1 64 300 300 (5760000)
# I0302 08:23:48.411296 13994 net.cpp:165] Memory required for data: 100800000
# I0302 08:23:48.411303 13994 layer_factory.hpp:77] Creating layer pool1
# I0302 08:23:48.411312 13994 net.cpp:100] Creating Layer pool1
# I0302 08:23:48.411319 13994 net.cpp:434] pool1 <- conv1_2
# I0302 08:23:48.411326 13994 net.cpp:408] pool1 -> pool1
# I0302 08:23:48.411360 13994 net.cpp:150] Setting up pool1
# I0302 08:23:48.411366 13994 net.cpp:157] Top shape: 1 64 150 150 (1440000)
# I0302 08:23:48.411371 13994 net.cpp:165] Memory required for data: 106560000
# I0302 08:23:48.411376 13994 layer_factory.hpp:77] Creating layer conv2_1
# I0302 08:23:48.411401 13994 net.cpp:100] Creating Layer conv2_1
# I0302 08:23:48.411408 13994 net.cpp:434] conv2_1 <- pool1
# I0302 08:23:48.411419 13994 net.cpp:408] conv2_1 -> conv2_1
# I0302 08:23:48.411895 13994 net.cpp:150] Setting up conv2_1
# I0302 08:23:48.411906 13994 net.cpp:157] Top shape: 1 128 150 150 (2880000)
# I0302 08:23:48.411911 13994 net.cpp:165] Memory required for data: 118080000
# I0302 08:23:48.411919 13994 layer_factory.hpp:77] Creating layer relu2_1
# I0302 08:23:48.411931 13994 net.cpp:100] Creating Layer relu2_1
# I0302 08:23:48.411939 13994 net.cpp:434] relu2_1 <- conv2_1
# I0302 08:23:48.411947 13994 net.cpp:395] relu2_1 -> conv2_1 (in-place)
# I0302 08:23:48.411957 13994 net.cpp:150] Setting up relu2_1
# I0302 08:23:48.411963 13994 net.cpp:157] Top shape: 1 128 150 150 (2880000)
# I0302 08:23:48.411974 13994 net.cpp:165] Memory required for data: 129600000
# I0302 08:23:48.411981 13994 layer_factory.hpp:77] Creating layer conv2_2
# I0302 08:23:48.411998 13994 net.cpp:100] Creating Layer conv2_2
# I0302 08:23:48.412006 13994 net.cpp:434] conv2_2 <- conv2_1
# I0302 08:23:48.412012 13994 net.cpp:408] conv2_2 -> conv2_2
# I0302 08:23:48.412871 13994 net.cpp:150] Setting up conv2_2
# I0302 08:23:48.412884 13994 net.cpp:157] Top shape: 1 128 150 150 (2880000)
# I0302 08:23:48.412891 13994 net.cpp:165] Memory required for data: 141120000
# I0302 08:23:48.412897 13994 layer_factory.hpp:77] Creating layer relu2_2
# I0302 08:23:48.412910 13994 net.cpp:100] Creating Layer relu2_2
# I0302 08:23:48.412918 13994 net.cpp:434] relu2_2 <- conv2_2
# I0302 08:23:48.412927 13994 net.cpp:395] relu2_2 -> conv2_2 (in-place)
# I0302 08:23:48.412937 13994 net.cpp:150] Setting up relu2_2
# I0302 08:23:48.412943 13994 net.cpp:157] Top shape: 1 128 150 150 (2880000)
# I0302 08:23:48.412951 13994 net.cpp:165] Memory required for data: 152640000
# I0302 08:23:48.412958 13994 layer_factory.hpp:77] Creating layer pool2
# I0302 08:23:48.412966 13994 net.cpp:100] Creating Layer pool2
# I0302 08:23:48.412972 13994 net.cpp:434] pool2 <- conv2_2
# I0302 08:23:48.412981 13994 net.cpp:408] pool2 -> pool2
# I0302 08:23:48.413012 13994 net.cpp:150] Setting up pool2
# I0302 08:23:48.413019 13994 net.cpp:157] Top shape: 1 128 75 75 (720000)
# I0302 08:23:48.413025 13994 net.cpp:165] Memory required for data: 155520000
# I0302 08:23:48.413033 13994 layer_factory.hpp:77] Creating layer conv3_1
# I0302 08:23:48.413044 13994 net.cpp:100] Creating Layer conv3_1
# I0302 08:23:48.413051 13994 net.cpp:434] conv3_1 <- pool2
# I0302 08:23:48.413062 13994 net.cpp:408] conv3_1 -> conv3_1
# I0302 08:23:48.415659 13994 net.cpp:150] Setting up conv3_1
# I0302 08:23:48.415676 13994 net.cpp:157] Top shape: 1 256 75 75 (1440000)
# I0302 08:23:48.415684 13994 net.cpp:165] Memory required for data: 161280000
# I0302 08:23:48.415694 13994 layer_factory.hpp:77] Creating layer relu3_1
# I0302 08:23:48.415702 13994 net.cpp:100] Creating Layer relu3_1
# I0302 08:23:48.415711 13994 net.cpp:434] relu3_1 <- conv3_1
# I0302 08:23:48.415719 13994 net.cpp:395] relu3_1 -> conv3_1 (in-place)
# I0302 08:23:48.415726 13994 net.cpp:150] Setting up relu3_1
# I0302 08:23:48.415733 13994 net.cpp:157] Top shape: 1 256 75 75 (1440000)
# I0302 08:23:48.415740 13994 net.cpp:165] Memory required for data: 167040000
# I0302 08:23:48.415745 13994 layer_factory.hpp:77] Creating layer conv3_2
# I0302 08:23:48.415756 13994 net.cpp:100] Creating Layer conv3_2
# I0302 08:23:48.415763 13994 net.cpp:434] conv3_2 <- conv3_1
# I0302 08:23:48.415773 13994 net.cpp:408] conv3_2 -> conv3_2
# I0302 08:23:48.419857 13994 net.cpp:150] Setting up conv3_2
# I0302 08:23:48.419871 13994 net.cpp:157] Top shape: 1 256 75 75 (1440000)
# I0302 08:23:48.419878 13994 net.cpp:165] Memory required for data: 172800000
# I0302 08:23:48.419884 13994 layer_factory.hpp:77] Creating layer relu3_2
# I0302 08:23:48.419895 13994 net.cpp:100] Creating Layer relu3_2
# I0302 08:23:48.419905 13994 net.cpp:434] relu3_2 <- conv3_2
# I0302 08:23:48.419912 13994 net.cpp:395] relu3_2 -> conv3_2 (in-place)
# I0302 08:23:48.419922 13994 net.cpp:150] Setting up relu3_2
# I0302 08:23:48.419929 13994 net.cpp:157] Top shape: 1 256 75 75 (1440000)
# I0302 08:23:48.419937 13994 net.cpp:165] Memory required for data: 178560000
# I0302 08:23:48.419945 13994 layer_factory.hpp:77] Creating layer conv3_3
# I0302 08:23:48.419960 13994 net.cpp:100] Creating Layer conv3_3
# I0302 08:23:48.419970 13994 net.cpp:434] conv3_3 <- conv3_2
# I0302 08:23:48.419975 13994 net.cpp:408] conv3_3 -> conv3_3
# I0302 08:23:48.424135 13994 net.cpp:150] Setting up conv3_3
# I0302 08:23:48.424154 13994 net.cpp:157] Top shape: 1 256 75 75 (1440000)
# I0302 08:23:48.424161 13994 net.cpp:165] Memory required for data: 184320000
# I0302 08:23:48.424167 13994 layer_factory.hpp:77] Creating layer relu3_3
# I0302 08:23:48.424176 13994 net.cpp:100] Creating Layer relu3_3
# I0302 08:23:48.424185 13994 net.cpp:434] relu3_3 <- conv3_3
# I0302 08:23:48.424189 13994 net.cpp:395] relu3_3 -> conv3_3 (in-place)
# I0302 08:23:48.424198 13994 net.cpp:150] Setting up relu3_3
# I0302 08:23:48.424207 13994 net.cpp:157] Top shape: 1 256 75 75 (1440000)
# I0302 08:23:48.424213 13994 net.cpp:165] Memory required for data: 190080000
# I0302 08:23:48.424219 13994 layer_factory.hpp:77] Creating layer pool3
# I0302 08:23:48.424227 13994 net.cpp:100] Creating Layer pool3
# I0302 08:23:48.424234 13994 net.cpp:434] pool3 <- conv3_3
# I0302 08:23:48.424240 13994 net.cpp:408] pool3 -> pool3
# I0302 08:23:48.424273 13994 net.cpp:150] Setting up pool3
# I0302 08:23:48.424280 13994 net.cpp:157] Top shape: 1 256 38 38 (369664)
# I0302 08:23:48.424288 13994 net.cpp:165] Memory required for data: 191558656
# I0302 08:23:48.424295 13994 layer_factory.hpp:77] Creating layer conv4_1
# I0302 08:23:48.424309 13994 net.cpp:100] Creating Layer conv4_1
# I0302 08:23:48.424315 13994 net.cpp:434] conv4_1 <- pool3
# I0302 08:23:48.424324 13994 net.cpp:408] conv4_1 -> conv4_1
# I0302 08:23:48.432525 13994 net.cpp:150] Setting up conv4_1
# I0302 08:23:48.432543 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.432550 13994 net.cpp:165] Memory required for data: 194515968
# I0302 08:23:48.432557 13994 layer_factory.hpp:77] Creating layer relu4_1
# I0302 08:23:48.432566 13994 net.cpp:100] Creating Layer relu4_1
# I0302 08:23:48.432579 13994 net.cpp:434] relu4_1 <- conv4_1
# I0302 08:23:48.432585 13994 net.cpp:395] relu4_1 -> conv4_1 (in-place)
# I0302 08:23:48.432592 13994 net.cpp:150] Setting up relu4_1
# I0302 08:23:48.432600 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.432605 13994 net.cpp:165] Memory required for data: 197473280
# I0302 08:23:48.432610 13994 layer_factory.hpp:77] Creating layer conv4_2
# I0302 08:23:48.432623 13994 net.cpp:100] Creating Layer conv4_2
# I0302 08:23:48.432631 13994 net.cpp:434] conv4_2 <- conv4_1
# I0302 08:23:48.432637 13994 net.cpp:408] conv4_2 -> conv4_2
# I0302 08:23:48.448547 13994 net.cpp:150] Setting up conv4_2
# I0302 08:23:48.448565 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.448571 13994 net.cpp:165] Memory required for data: 200430592
# I0302 08:23:48.448581 13994 layer_factory.hpp:77] Creating layer relu4_2
# I0302 08:23:48.448592 13994 net.cpp:100] Creating Layer relu4_2
# I0302 08:23:48.448602 13994 net.cpp:434] relu4_2 <- conv4_2
# I0302 08:23:48.448609 13994 net.cpp:395] relu4_2 -> conv4_2 (in-place)
# I0302 08:23:48.448617 13994 net.cpp:150] Setting up relu4_2
# I0302 08:23:48.448624 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.448632 13994 net.cpp:165] Memory required for data: 203387904
# I0302 08:23:48.448637 13994 layer_factory.hpp:77] Creating layer conv4_3
# I0302 08:23:48.448647 13994 net.cpp:100] Creating Layer conv4_3
# I0302 08:23:48.448658 13994 net.cpp:434] conv4_3 <- conv4_2
# I0302 08:23:48.448668 13994 net.cpp:408] conv4_3 -> conv4_3
# I0302 08:23:48.464394 13994 net.cpp:150] Setting up conv4_3
# I0302 08:23:48.464411 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.464419 13994 net.cpp:165] Memory required for data: 206345216
# I0302 08:23:48.464426 13994 layer_factory.hpp:77] Creating layer relu4_3
# I0302 08:23:48.464435 13994 net.cpp:100] Creating Layer relu4_3
# I0302 08:23:48.464444 13994 net.cpp:434] relu4_3 <- conv4_3
# I0302 08:23:48.464452 13994 net.cpp:395] relu4_3 -> conv4_3 (in-place)
# I0302 08:23:48.464464 13994 net.cpp:150] Setting up relu4_3
# I0302 08:23:48.464468 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.464474 13994 net.cpp:165] Memory required for data: 209302528
# I0302 08:23:48.464480 13994 layer_factory.hpp:77] Creating layer conv4_3_relu4_3_0_split
# I0302 08:23:48.464488 13994 net.cpp:100] Creating Layer conv4_3_relu4_3_0_split
# I0302 08:23:48.464494 13994 net.cpp:434] conv4_3_relu4_3_0_split <- conv4_3
# I0302 08:23:48.464500 13994 net.cpp:408] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_0
# I0302 08:23:48.464510 13994 net.cpp:408] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_1
# I0302 08:23:48.464542 13994 net.cpp:150] Setting up conv4_3_relu4_3_0_split
# I0302 08:23:48.464550 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.464555 13994 net.cpp:157] Top shape: 1 512 38 38 (739328)
# I0302 08:23:48.464560 13994 net.cpp:165] Memory required for data: 215217152
# I0302 08:23:48.464567 13994 layer_factory.hpp:77] Creating layer pool4
# I0302 08:23:48.464579 13994 net.cpp:100] Creating Layer pool4
# I0302 08:23:48.464587 13994 net.cpp:434] pool4 <- conv4_3_relu4_3_0_split_0
# I0302 08:23:48.464596 13994 net.cpp:408] pool4 -> pool4
# I0302 08:23:48.464627 13994 net.cpp:150] Setting up pool4
# I0302 08:23:48.464635 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.464640 13994 net.cpp:165] Memory required for data: 215956480
# I0302 08:23:48.464648 13994 layer_factory.hpp:77] Creating layer conv5_1
# I0302 08:23:48.464666 13994 net.cpp:100] Creating Layer conv5_1
# I0302 08:23:48.464675 13994 net.cpp:434] conv5_1 <- pool4
# I0302 08:23:48.464685 13994 net.cpp:408] conv5_1 -> conv5_1
# I0302 08:23:48.481241 13994 net.cpp:150] Setting up conv5_1
# I0302 08:23:48.481261 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.481269 13994 net.cpp:165] Memory required for data: 216695808
# I0302 08:23:48.481276 13994 layer_factory.hpp:77] Creating layer relu5_1
# I0302 08:23:48.481287 13994 net.cpp:100] Creating Layer relu5_1
# I0302 08:23:48.481297 13994 net.cpp:434] relu5_1 <- conv5_1
# I0302 08:23:48.481304 13994 net.cpp:395] relu5_1 -> conv5_1 (in-place)
# I0302 08:23:48.481313 13994 net.cpp:150] Setting up relu5_1
# I0302 08:23:48.481320 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.481326 13994 net.cpp:165] Memory required for data: 217435136
# I0302 08:23:48.481331 13994 layer_factory.hpp:77] Creating layer conv5_2
# I0302 08:23:48.481348 13994 net.cpp:100] Creating Layer conv5_2
# I0302 08:23:48.481356 13994 net.cpp:434] conv5_2 <- conv5_1
# I0302 08:23:48.481365 13994 net.cpp:408] conv5_2 -> conv5_2
# I0302 08:23:48.497963 13994 net.cpp:150] Setting up conv5_2
# I0302 08:23:48.497983 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.497990 13994 net.cpp:165] Memory required for data: 218174464
# I0302 08:23:48.497997 13994 layer_factory.hpp:77] Creating layer relu5_2
# I0302 08:23:48.498004 13994 net.cpp:100] Creating Layer relu5_2
# I0302 08:23:48.498011 13994 net.cpp:434] relu5_2 <- conv5_2
# I0302 08:23:48.498020 13994 net.cpp:395] relu5_2 -> conv5_2 (in-place)
# I0302 08:23:48.498032 13994 net.cpp:150] Setting up relu5_2
# I0302 08:23:48.498036 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.498042 13994 net.cpp:165] Memory required for data: 218913792
# I0302 08:23:48.498047 13994 layer_factory.hpp:77] Creating layer conv5_3
# I0302 08:23:48.498060 13994 net.cpp:100] Creating Layer conv5_3
# I0302 08:23:48.498068 13994 net.cpp:434] conv5_3 <- conv5_2
# I0302 08:23:48.498077 13994 net.cpp:408] conv5_3 -> conv5_3
# I0302 08:23:48.514140 13994 net.cpp:150] Setting up conv5_3
# I0302 08:23:48.514164 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.514171 13994 net.cpp:165] Memory required for data: 219653120
# I0302 08:23:48.514179 13994 layer_factory.hpp:77] Creating layer relu5_3
# I0302 08:23:48.514195 13994 net.cpp:100] Creating Layer relu5_3
# I0302 08:23:48.514204 13994 net.cpp:434] relu5_3 <- conv5_3
# I0302 08:23:48.514210 13994 net.cpp:395] relu5_3 -> conv5_3 (in-place)
# I0302 08:23:48.514219 13994 net.cpp:150] Setting up relu5_3
# I0302 08:23:48.514225 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.514232 13994 net.cpp:165] Memory required for data: 220392448
# I0302 08:23:48.514236 13994 layer_factory.hpp:77] Creating layer pool5
# I0302 08:23:48.514250 13994 net.cpp:100] Creating Layer pool5
# I0302 08:23:48.514257 13994 net.cpp:434] pool5 <- conv5_3
# I0302 08:23:48.514264 13994 net.cpp:408] pool5 -> pool5
# I0302 08:23:48.514298 13994 net.cpp:150] Setting up pool5
# I0302 08:23:48.514305 13994 net.cpp:157] Top shape: 1 512 19 19 (184832)
# I0302 08:23:48.514310 13994 net.cpp:165] Memory required for data: 221131776
# I0302 08:23:48.514314 13994 layer_factory.hpp:77] Creating layer fc6
# I0302 08:23:48.514328 13994 net.cpp:100] Creating Layer fc6
# I0302 08:23:48.514335 13994 net.cpp:434] fc6 <- pool5
# I0302 08:23:48.514343 13994 net.cpp:408] fc6 -> fc6
# I0302 08:23:48.548445 13994 net.cpp:150] Setting up fc6
# I0302 08:23:48.548470 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.548477 13994 net.cpp:165] Memory required for data: 222610432
# I0302 08:23:48.548486 13994 layer_factory.hpp:77] Creating layer relu6
# I0302 08:23:48.548497 13994 net.cpp:100] Creating Layer relu6
# I0302 08:23:48.548503 13994 net.cpp:434] relu6 <- fc6
# I0302 08:23:48.548514 13994 net.cpp:395] relu6 -> fc6 (in-place)
# I0302 08:23:48.548529 13994 net.cpp:150] Setting up relu6
# I0302 08:23:48.548534 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.548540 13994 net.cpp:165] Memory required for data: 224089088
# I0302 08:23:48.548547 13994 layer_factory.hpp:77] Creating layer fc7
# I0302 08:23:48.548557 13994 net.cpp:100] Creating Layer fc7
# I0302 08:23:48.548565 13994 net.cpp:434] fc7 <- fc6
# I0302 08:23:48.548573 13994 net.cpp:408] fc7 -> fc7
# I0302 08:23:48.555814 13994 net.cpp:150] Setting up fc7
# I0302 08:23:48.555835 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.555843 13994 net.cpp:165] Memory required for data: 225567744
# I0302 08:23:48.555851 13994 layer_factory.hpp:77] Creating layer relu7
# I0302 08:23:48.555860 13994 net.cpp:100] Creating Layer relu7
# I0302 08:23:48.555866 13994 net.cpp:434] relu7 <- fc7
# I0302 08:23:48.555873 13994 net.cpp:395] relu7 -> fc7 (in-place)
# I0302 08:23:48.555886 13994 net.cpp:150] Setting up relu7
# I0302 08:23:48.555889 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.555897 13994 net.cpp:165] Memory required for data: 227046400
# I0302 08:23:48.555903 13994 layer_factory.hpp:77] Creating layer fc7_relu7_0_split
# I0302 08:23:48.555912 13994 net.cpp:100] Creating Layer fc7_relu7_0_split
# I0302 08:23:48.555918 13994 net.cpp:434] fc7_relu7_0_split <- fc7
# I0302 08:23:48.555928 13994 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_0
# I0302 08:23:48.555940 13994 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_1
# I0302 08:23:48.555950 13994 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_2
# I0302 08:23:48.555964 13994 net.cpp:408] fc7_relu7_0_split -> fc7_relu7_0_split_3
# I0302 08:23:48.556006 13994 net.cpp:150] Setting up fc7_relu7_0_split
# I0302 08:23:48.556013 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.556018 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.556026 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.556035 13994 net.cpp:157] Top shape: 1 1024 19 19 (369664)
# I0302 08:23:48.556042 13994 net.cpp:165] Memory required for data: 232961024
# I0302 08:23:48.556049 13994 layer_factory.hpp:77] Creating layer conv6_1
# I0302 08:23:48.556066 13994 net.cpp:100] Creating Layer conv6_1
# I0302 08:23:48.556072 13994 net.cpp:434] conv6_1 <- fc7_relu7_0_split_0
# I0302 08:23:48.556082 13994 net.cpp:408] conv6_1 -> conv6_1
# I0302 08:23:48.558526 13994 net.cpp:150] Setting up conv6_1
# I0302 08:23:48.558545 13994 net.cpp:157] Top shape: 1 256 19 19 (92416)
# I0302 08:23:48.558552 13994 net.cpp:165] Memory required for data: 233330688
# I0302 08:23:48.558560 13994 layer_factory.hpp:77] Creating layer conv6_1_relu
# I0302 08:23:48.558573 13994 net.cpp:100] Creating Layer conv6_1_relu
# I0302 08:23:48.558580 13994 net.cpp:434] conv6_1_relu <- conv6_1
# I0302 08:23:48.558590 13994 net.cpp:395] conv6_1_relu -> conv6_1 (in-place)
# I0302 08:23:48.558601 13994 net.cpp:150] Setting up conv6_1_relu
# I0302 08:23:48.558609 13994 net.cpp:157] Top shape: 1 256 19 19 (92416)
# I0302 08:23:48.558614 13994 net.cpp:165] Memory required for data: 233700352
# I0302 08:23:48.558619 13994 layer_factory.hpp:77] Creating layer conv6_2
# I0302 08:23:48.558630 13994 net.cpp:100] Creating Layer conv6_2
# I0302 08:23:48.558637 13994 net.cpp:434] conv6_2 <- conv6_1
# I0302 08:23:48.558645 13994 net.cpp:408] conv6_2 -> conv6_2
# I0302 08:23:48.566778 13994 net.cpp:150] Setting up conv6_2
# I0302 08:23:48.566795 13994 net.cpp:157] Top shape: 1 512 10 10 (51200)
# I0302 08:23:48.566802 13994 net.cpp:165] Memory required for data: 233905152
# I0302 08:23:48.566818 13994 layer_factory.hpp:77] Creating layer conv6_2_relu
# I0302 08:23:48.566833 13994 net.cpp:100] Creating Layer conv6_2_relu
# I0302 08:23:48.566838 13994 net.cpp:434] conv6_2_relu <- conv6_2
# I0302 08:23:48.566848 13994 net.cpp:395] conv6_2_relu -> conv6_2 (in-place)
# I0302 08:23:48.566859 13994 net.cpp:150] Setting up conv6_2_relu
# I0302 08:23:48.566865 13994 net.cpp:157] Top shape: 1 512 10 10 (51200)
# I0302 08:23:48.566874 13994 net.cpp:165] Memory required for data: 234109952
# I0302 08:23:48.566880 13994 layer_factory.hpp:77] Creating layer conv6_2_conv6_2_relu_0_split
# I0302 08:23:48.566892 13994 net.cpp:100] Creating Layer conv6_2_conv6_2_relu_0_split
# I0302 08:23:48.566900 13994 net.cpp:434] conv6_2_conv6_2_relu_0_split <- conv6_2
# ...
# I0302 08:23:48.695518 13994 net.cpp:150] Setting up pool6_mbox_conf_flat
# I0302 08:23:48.695523 13994 net.cpp:157] Top shape: 1 28 (28)
# I0302 08:23:48.695528 13994 net.cpp:165] Memory required for data: 249623232
# I0302 08:23:48.695533 13994 layer_factory.hpp:77] Creating layer pool6_mbox_priorbox
# I0302 08:23:48.695540 13994 net.cpp:100] Creating Layer pool6_mbox_priorbox
# I0302 08:23:48.695545 13994 net.cpp:434] pool6_mbox_priorbox <- pool6_pool6_0_split_2
# I0302 08:23:48.695550 13994 net.cpp:434] pool6_mbox_priorbox <- data_input_0_split_6
# I0302 08:23:48.695559 13994 net.cpp:408] pool6_mbox_priorbox -> pool6_mbox_priorbox
# I0302 08:23:48.695578 13994 net.cpp:150] Setting up pool6_mbox_priorbox
# I0302 08:23:48.695582 13994 net.cpp:157] Top shape: 1 2 56 (112)
# I0302 08:23:48.695587 13994 net.cpp:165] Memory required for data: 249623680
# I0302 08:23:48.695591 13994 layer_factory.hpp:77] Creating layer mbox_loc
# I0302 08:23:48.695873 13994 net.cpp:100] Creating Layer mbox_loc
# I0302 08:23:48.695888 13994 net.cpp:434] mbox_loc <- conv4_3_norm_mbox_loc_flat
# I0302 08:23:48.695897 13994 net.cpp:434] mbox_loc <- fc7_mbox_loc_flat
# I0302 08:23:48.695902 13994 net.cpp:434] mbox_loc <- conv6_2_mbox_loc_flat
# I0302 08:23:48.695909 13994 net.cpp:434] mbox_loc <- conv7_2_mbox_loc_flat
# I0302 08:23:48.695914 13994 net.cpp:434] mbox_loc <- conv8_2_mbox_loc_flat
# I0302 08:23:48.695919 13994 net.cpp:434] mbox_loc <- pool6_mbox_loc_flat
# I0302 08:23:48.695931 13994 net.cpp:408] mbox_loc -> mbox_loc
# I0302 08:23:48.695981 13994 net.cpp:150] Setting up mbox_loc
# I0302 08:23:48.695986 13994 net.cpp:157] Top shape: 1 97088 (97088)
# I0302 08:23:48.695991 13994 net.cpp:165] Memory required for data: 250012032
# I0302 08:23:48.695996 13994 layer_factory.hpp:77] Creating layer mbox_conf
# I0302 08:23:48.696007 13994 net.cpp:100] Creating Layer mbox_conf
# I0302 08:23:48.696012 13994 net.cpp:434] mbox_conf <- conv4_3_norm_mbox_conf_flat
# I0302 08:23:48.696017 13994 net.cpp:434] mbox_conf <- fc7_mbox_conf_flat
# I0302 08:23:48.696022 13994 net.cpp:434] mbox_conf <- conv6_2_mbox_conf_flat
# I0302 08:23:48.696027 13994 net.cpp:434] mbox_conf <- conv7_2_mbox_conf_flat
# I0302 08:23:48.696033 13994 net.cpp:434] mbox_conf <- conv8_2_mbox_conf_flat
# I0302 08:23:48.696038 13994 net.cpp:434] mbox_conf <- pool6_mbox_conf_flat
# I0302 08:23:48.696044 13994 net.cpp:408] mbox_conf -> mbox_conf
# I0302 08:23:48.696064 13994 net.cpp:150] Setting up mbox_conf
# I0302 08:23:48.696069 13994 net.cpp:157] Top shape: 1 48544 (48544)
# I0302 08:23:48.696074 13994 net.cpp:165] Memory required for data: 250206208
# I0302 08:23:48.696077 13994 layer_factory.hpp:77] Creating layer mbox_priorbox
# I0302 08:23:48.696084 13994 net.cpp:100] Creating Layer mbox_priorbox
# I0302 08:23:48.696089 13994 net.cpp:434] mbox_priorbox <- conv4_3_norm_mbox_priorbox
# I0302 08:23:48.696095 13994 net.cpp:434] mbox_priorbox <- fc7_mbox_priorbox
# I0302 08:23:48.696100 13994 net.cpp:434] mbox_priorbox <- conv6_2_mbox_priorbox
# I0302 08:23:48.696105 13994 net.cpp:434] mbox_priorbox <- conv7_2_mbox_priorbox
# I0302 08:23:48.696110 13994 net.cpp:434] mbox_priorbox <- conv8_2_mbox_priorbox
# I0302 08:23:48.696115 13994 net.cpp:434] mbox_priorbox <- pool6_mbox_priorbox
# I0302 08:23:48.696121 13994 net.cpp:408] mbox_priorbox -> mbox_priorbox
# I0302 08:23:48.696141 13994 net.cpp:150] Setting up mbox_priorbox
# I0302 08:23:48.696144 13994 net.cpp:157] Top shape: 1 2 97088 (194176)
# I0302 08:23:48.696151 13994 net.cpp:165] Memory required for data: 250982912
# I0302 08:23:48.696156 13994 layer_factory.hpp:77] Creating layer mbox_conf_reshape
# I0302 08:23:48.696170 13994 net.cpp:100] Creating Layer mbox_conf_reshape
# I0302 08:23:48.696174 13994 net.cpp:434] mbox_conf_reshape <- mbox_conf
# I0302 08:23:48.696182 13994 net.cpp:408] mbox_conf_reshape -> mbox_conf_reshape
# I0302 08:23:48.696208 13994 net.cpp:150] Setting up mbox_conf_reshape
# I0302 08:23:48.696213 13994 net.cpp:157] Top shape: 1 24272 2 (48544)
# I0302 08:23:48.696218 13994 net.cpp:165] Memory required for data: 251177088
# I0302 08:23:48.696223 13994 layer_factory.hpp:77] Creating layer mbox_conf_softmax
# I0302 08:23:48.696230 13994 net.cpp:100] Creating Layer mbox_conf_softmax
# I0302 08:23:48.696235 13994 net.cpp:434] mbox_conf_softmax <- mbox_conf_reshape
# I0302 08:23:48.696241 13994 net.cpp:408] mbox_conf_softmax -> mbox_conf_softmax
# I0302 08:23:48.696287 13994 net.cpp:150] Setting up mbox_conf_softmax
# I0302 08:23:48.696293 13994 net.cpp:157] Top shape: 1 24272 2 (48544)
# I0302 08:23:48.696298 13994 net.cpp:165] Memory required for data: 251371264
# I0302 08:23:48.696302 13994 layer_factory.hpp:77] Creating layer mbox_conf_flatten
# I0302 08:23:48.696309 13994 net.cpp:100] Creating Layer mbox_conf_flatten
# I0302 08:23:48.696314 13994 net.cpp:434] mbox_conf_flatten <- mbox_conf_softmax
# I0302 08:23:48.696319 13994 net.cpp:408] mbox_conf_flatten -> mbox_conf_flatten
# I0302 08:23:48.696336 13994 net.cpp:150] Setting up mbox_conf_flatten
# I0302 08:23:48.696341 13994 net.cpp:157] Top shape: 1 48544 (48544)
# I0302 08:23:48.696345 13994 net.cpp:165] Memory required for data: 251565440
# I0302 08:23:48.696349 13994 layer_factory.hpp:77] Creating layer detection_out
# I0302 08:23:48.696363 13994 net.cpp:100] Creating Layer detection_out
# I0302 08:23:48.696367 13994 net.cpp:434] detection_out <- mbox_loc
# I0302 08:23:48.696372 13994 net.cpp:434] detection_out <- mbox_conf_flatten
# I0302 08:23:48.696377 13994 net.cpp:434] detection_out <- mbox_priorbox
# I0302 08:23:48.696384 13994 net.cpp:408] detection_out -> detection_out
# I0302 08:23:48.697685 13994 net.cpp:150] Setting up detection_out
# I0302 08:23:48.697703 13994 net.cpp:157] Top shape: 1 1 1 7 (7)
# I0302 08:23:48.697711 13994 net.cpp:165] Memory required for data: 251565468
# I0302 08:23:48.697719 13994 net.cpp:228] detection_out does not need backward computation.
# I0302 08:23:48.697728 13994 net.cpp:228] mbox_conf_flatten does not need backward computation.
# I0302 08:23:48.697736 13994 net.cpp:228] mbox_conf_softmax does not need backward computation.
# I0302 08:23:48.697741 13994 net.cpp:228] mbox_conf_reshape does not need backward computation.
# I0302 08:23:48.697747 13994 net.cpp:228] mbox_priorbox does not need backward computation.
# I0302 08:23:48.697755 13994 net.cpp:228] mbox_conf does not need backward computation.
# I0302 08:23:48.697764 13994 net.cpp:228] mbox_loc does not need backward computation.
# I0302 08:23:48.697773 13994 net.cpp:228] pool6_mbox_priorbox does not need backward computation.
# I0302 08:23:48.697782 13994 net.cpp:228] pool6_mbox_conf_flat does not need backward computation.
# I0302 08:23:48.697789 13994 net.cpp:228] pool6_mbox_conf_perm does not need backward computation.
# I0302 08:23:48.697796 13994 net.cpp:228] pool6_mbox_conf does not need backward computation.
# I0302 08:23:48.697803 13994 net.cpp:228] pool6_mbox_loc_flat does not need backward computation.
# I0302 08:23:48.697809 13994 net.cpp:228] pool6_mbox_loc_perm does not need backward computation.
# I0302 08:23:48.697816 13994 net.cpp:228] pool6_mbox_loc does not need backward computation.
# I0302 08:23:48.697824 13994 net.cpp:228] conv8_2_mbox_priorbox does not need backward computation.
# I0302 08:23:48.697830 13994 net.cpp:228] conv8_2_mbox_conf_flat does not need backward computation.
# I0302 08:23:48.697839 13994 net.cpp:228] conv8_2_mbox_conf_perm does not need backward computation.
# I0302 08:23:48.697845 13994 net.cpp:228] conv8_2_mbox_conf does not need backward computation.
# I0302 08:23:48.697852 13994 net.cpp:228] conv8_2_mbox_loc_flat does not need backward computation.
# I0302 08:23:48.697860 13994 net.cpp:228] conv8_2_mbox_loc_perm does not need backward computation.
# I0302 08:23:48.697865 13994 net.cpp:228] conv8_2_mbox_loc does not need backward computation.
# I0302 08:23:48.697871 13994 net.cpp:228] conv7_2_mbox_priorbox does not need backward computation.
# I0302 08:23:48.697878 13994 net.cpp:228] conv7_2_mbox_conf_flat does not need backward computation.
# I0302 08:23:48.697886 13994 net.cpp:228] conv7_2_mbox_conf_perm does not need backward computation.
# I0302 08:23:48.697892 13994 net.cpp:228] conv7_2_mbox_conf does not need backward computation.
# I0302 08:23:48.697899 13994 net.cpp:228] conv7_2_mbox_loc_flat does not need backward computation.
# I0302 08:23:48.697906 13994 net.cpp:228] conv7_2_mbox_loc_perm does not need backward computation.
# I0302 08:23:48.697914 13994 net.cpp:228] conv7_2_mbox_loc does not need backward computation.
# I0302 08:23:48.697921 13994 net.cpp:228] conv6_2_mbox_priorbox does not need backward computation.
# I0302 08:23:48.697929 13994 net.cpp:228] conv6_2_mbox_conf_flat does not need backward computation.
# I0302 08:23:48.697937 13994 net.cpp:228] conv6_2_mbox_conf_perm does not need backward computation.
# I0302 08:23:48.697943 13994 net.cpp:228] conv6_2_mbox_conf does not need backward computation.
# I0302 08:23:48.697950 13994 net.cpp:228] conv6_2_mbox_loc_flat does not need backward computation.
# I0302 08:23:48.697957 13994 net.cpp:228] conv6_2_mbox_loc_perm does not need backward computation.
# I0302 08:23:48.697963 13994 net.cpp:228] conv6_2_mbox_loc does not need backward computation.
# I0302 08:23:48.697971 13994 net.cpp:228] fc7_mbox_priorbox does not need backward computation.
# I0302 08:23:48.697978 13994 net.cpp:228] fc7_mbox_conf_flat does not need backward computation.
# I0302 08:23:48.697985 13994 net.cpp:228] fc7_mbox_conf_perm does not need backward computation.
# I0302 08:23:48.697993 13994 net.cpp:228] fc7_mbox_conf does not need backward computation.
# I0302 08:23:48.697999 13994 net.cpp:228] fc7_mbox_loc_flat does not need backward computation.
# I0302 08:23:48.698006 13994 net.cpp:228] fc7_mbox_loc_perm does not need backward computation.
# I0302 08:23:48.698014 13994 net.cpp:228] fc7_mbox_loc does not need backward computation.
# I0302 08:23:48.698021 13994 net.cpp:228] conv4_3_norm_mbox_priorbox does not need backward computation.
# I0302 08:23:48.698029 13994 net.cpp:228] conv4_3_norm_mbox_conf_flat does not need backward computation.
# I0302 08:23:48.698035 13994 net.cpp:228] conv4_3_norm_mbox_conf_perm does not need backward computation.
# I0302 08:23:48.698042 13994 net.cpp:228] conv4_3_norm_mbox_conf does not need backward computation.
# I0302 08:23:48.698050 13994 net.cpp:228] conv4_3_norm_mbox_loc_flat does not need backward computation.
# I0302 08:23:48.698056 13994 net.cpp:228] conv4_3_norm_mbox_loc_perm does not need backward computation.
# I0302 08:23:48.698062 13994 net.cpp:228] conv4_3_norm_mbox_loc does not need backward computation.
# I0302 08:23:48.698069 13994 net.cpp:228] conv4_3_norm_conv4_3_norm_0_split does not need backward computation.
# I0302 08:23:48.698076 13994 net.cpp:228] conv4_3_norm does not need backward computation.
# I0302 08:23:48.698083 13994 net.cpp:228] pool6_pool6_0_split does not need backward computation.
# I0302 08:23:48.698091 13994 net.cpp:228] pool6 does not need backward computation.
# I0302 08:23:48.698097 13994 net.cpp:228] conv8_2_conv8_2_relu_0_split does not need backward computation.
# I0302 08:23:48.698104 13994 net.cpp:228] conv8_2_relu does not need backward computation.
# I0302 08:23:48.698112 13994 net.cpp:228] conv8_2 does not need backward computation.
# I0302 08:23:48.698117 13994 net.cpp:228] conv8_1_relu does not need backward computation.
# I0302 08:23:48.698124 13994 net.cpp:228] conv8_1 does not need backward computation.
# I0302 08:23:48.698132 13994 net.cpp:228] conv7_2_conv7_2_relu_0_split does not need backward computation.
# I0302 08:23:48.698139 13994 net.cpp:228] conv7_2_relu does not need backward computation.
# I0302 08:23:48.698146 13994 net.cpp:228] conv7_2 does not need backward computation.
# I0302 08:23:48.698153 13994 net.cpp:228] conv7_1_relu does not need backward computation.
# I0302 08:23:48.698160 13994 net.cpp:228] conv7_1 does not need backward computation.
# I0302 08:23:48.698168 13994 net.cpp:228] conv6_2_conv6_2_relu_0_split does not need backward computation.
# I0302 08:23:48.698176 13994 net.cpp:228] conv6_2_relu does not need backward computation.
# I0302 08:23:48.698184 13994 net.cpp:228] conv6_2 does not need backward computation.
# I0302 08:23:48.698190 13994 net.cpp:228] conv6_1_relu does not need backward computation.
# I0302 08:23:48.698197 13994 net.cpp:228] conv6_1 does not need backward computation.
# I0302 08:23:48.698204 13994 net.cpp:228] fc7_relu7_0_split does not need backward computation.
# I0302 08:23:48.698212 13994 net.cpp:228] relu7 does not need backward computation.
# I0302 08:23:48.698218 13994 net.cpp:228] fc7 does not need backward computation.
# I0302 08:23:48.698225 13994 net.cpp:228] relu6 does not need backward computation.
# I0302 08:23:48.698232 13994 net.cpp:228] fc6 does not need backward computation.
# I0302 08:23:48.698240 13994 net.cpp:228] pool5 does not need backward computation.
# I0302 08:23:48.698246 13994 net.cpp:228] relu5_3 does not need backward computation.
# I0302 08:23:48.698253 13994 net.cpp:228] conv5_3 does not need backward computation.
# I0302 08:23:48.698261 13994 net.cpp:228] relu5_2 does not need backward computation.
# I0302 08:23:48.698267 13994 net.cpp:228] conv5_2 does not need backward computation.
# I0302 08:23:48.698274 13994 net.cpp:228] relu5_1 does not need backward computation.
# I0302 08:23:48.698280 13994 net.cpp:228] conv5_1 does not need backward computation.
# I0302 08:23:48.698287 13994 net.cpp:228] pool4 does not need backward computation.
# I0302 08:23:48.698294 13994 net.cpp:228] conv4_3_relu4_3_0_split does not need backward computation.
# I0302 08:23:48.698302 13994 net.cpp:228] relu4_3 does not need backward computation.
# I0302 08:23:48.698307 13994 net.cpp:228] conv4_3 does not need backward computation.
# I0302 08:23:48.698314 13994 net.cpp:228] relu4_2 does not need backward computation.
# I0302 08:23:48.698320 13994 net.cpp:228] conv4_2 does not need backward computation.
# I0302 08:23:48.698328 13994 net.cpp:228] relu4_1 does not need backward computation.
# I0302 08:23:48.698335 13994 net.cpp:228] conv4_1 does not need backward computation.
# I0302 08:23:48.698341 13994 net.cpp:228] pool3 does not need backward computation.
# I0302 08:23:48.698347 13994 net.cpp:228] relu3_3 does not need backward computation.
# I0302 08:23:48.698354 13994 net.cpp:228] conv3_3 does not need backward computation.
# I0302 08:23:48.698361 13994 net.cpp:228] relu3_2 does not need backward computation.
# I0302 08:23:48.698367 13994 net.cpp:228] conv3_2 does not need backward computation.
# I0302 08:23:48.698374 13994 net.cpp:228] relu3_1 does not need backward computation.
# I0302 08:23:48.698380 13994 net.cpp:228] conv3_1 does not need backward computation.
# I0302 08:23:48.698396 13994 net.cpp:228] pool2 does not need backward computation.
# I0302 08:23:48.698405 13994 net.cpp:228] relu2_2 does not need backward computation.
# I0302 08:23:48.698411 13994 net.cpp:228] conv2_2 does not need backward computation.
# I0302 08:23:48.698418 13994 net.cpp:228] relu2_1 does not need backward computation.
# I0302 08:23:48.698424 13994 net.cpp:228] conv2_1 does not need backward computation.
# I0302 08:23:48.698431 13994 net.cpp:228] pool1 does not need backward computation.
# I0302 08:23:48.698436 13994 net.cpp:228] relu1_2 does not need backward computation.
# I0302 08:23:48.698443 13994 net.cpp:228] conv1_2 does not need backward computation.
# I0302 08:23:48.698451 13994 net.cpp:228] relu1_1 does not need backward computation.
# I0302 08:23:48.698459 13994 net.cpp:228] conv1_1 does not need backward computation.
# I0302 08:23:48.698467 13994 net.cpp:228] data_input_0_split does not need backward computation.
# I0302 08:23:48.698477 13994 net.cpp:228] input does not need backward computation.
# I0302 08:23:48.698482 13994 net.cpp:270] This network produces output detection_out
# I0302 08:23:48.698583 13994 net.cpp:283] Network initialization done.
# I0302 08:23:48.939237 13994 net.cpp:761] Ignoring source layer data
# I0302 08:23:48.939272 13994 net.cpp:761] Ignoring source layer data_data_0_split
# I0302 08:23:48.963428 13994 net.cpp:761] Ignoring source layer mbox_loss
# (700, 700)
# success
